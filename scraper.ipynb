# %%
import pandas as pd
import numpy as np
import requests
import re
import logging
from bs4 import BeautifulSoup
import sys

# %%
df = pd.read_excel('data/cluster.xlsx')
package_names = list(df['Unnamed: 1'])
package_names
# Out:
# ['ant:ant',
#  'org.apache.ant:ant',
#  'org.apache.ant:ant-apache-regexp',
#  'org.apache.ant:ant-junit',
#  'org.apache.ant:ant-nodeps',
#  'org.apache.ant:ant-trax',
#  'commons-io:commons-io',
#  'org.apache.commons:commons-io',
#  'org.codehaus.plexus:plexus-utils',
#  'antlr:antlr',
#  'org.antlr:antlr-runtime',
#  'org.antlr:antlr4-runtime',
#  'com.tunnelvisionlabs:antlr4-runtime',
#  'org.codehaus.mojo:javacc-maven-plugin',
#  'org.parboiled:parboiled-java',
#  'antlr:stringtemplate',
#  'org.antlr:stringtemplate',
#  'aopalliance:aopalliance',
#  'com.google.inject.extensions:guice-jmx',
#  'com.google.inject:guice',
#  'org.springframework:spring-beans',
#  'org.springframework:spring-context',
#  'org.springframework:spring-core',
#  'com.google.inject.extensions:guice-assistedinject',
#  'com.google.gwt.inject:gin',
#  'com.squareup.dagger:dagger',
#  'com.squareup.dagger:dagger-compiler',
#  'com.google.inject.extensions:guice-multibindings',
#  'org.sonatype.sisu:sisu-guice',
#  'com.google.inject.extensions:guice-servlet',
#  'com.github.rtyley:roboguice-sherlock',
#  'com.google.dagger:dagger',
#  'com.google.dagger:dagger-compiler',
#  'javax.inject:javax.inject',
#  'org.roboguice:roboguice',
#  'javax.annotation:javax.annotation-api',
#  'org.apache.geronimo.specs:geronimo-annotation_1.3_spec',
#  'org.jboss.spec.javax.annotation:jboss-annotations-api_1.3_spec',
#  'javax.el:javax.el-api',
#  'jakarta.el:jakarta.el-api',
#  'org.glassfish:javax.el',
#  'javax.enterprise:cdi-api',
#  'jakarta.enterprise:jakarta.enterprise.cdi-api',
#  'org.apache.geronimo.specs:geronimo-atinject_1.0_spec',
#  'org.apache.servicemix.bundles:org.apache.servicemix.bundles.javax-inject',
#  'javax.json:javax.json-api',
#  'jakarta.json:jakarta.json-api',
#  'javax.json.bind:javax.json.bind-api',
#  'org.glassfish:javax.json',
#  'javax.persistence:persistence-api',
#  'org.eclipse.persistence:javax.persistence',
#  'org.hibernate.javax.persistence:hibernate-jpa-2.1-api',
#  'org.hibernate:hibernate-core',
#  'jakarta.validation:jakarta.validation-api',
#  'javax.transaction:javax.transaction-api',
#  'org.jboss.spec.javax.transaction:jboss-transaction-api_1.1_spec',
#  'org.jboss.spec:jboss-javaee-6.0',
#  'javax.transaction:jta',
#  'org.apache.geronimo.specs:geronimo-jta_1.1_spec',
#  'org.jboss.spec.javax.transaction:jboss-transaction-api_1.2_spec',
#  'javax.validation:validation-api',
#  'javax.ws.rs:javax.ws.rs-api',
#  'jakarta.ws.rs:jakarta.ws.rs-api',
#  'org.jboss.spec.javax.ws.rs:jboss-jaxrs-api_2.1_spec',
#  'javax:javaee-api',
#  'javax.persistence:javax.persistence-api',
#  'org.jboss.spec.javax.interceptor:jboss-interceptors-api_1.2_spec',
#  'org.apache.activemq:activemq-client',
#  'org.apache.geronimo.specs:geronimo-jms_1.1_spec',
#  'javax.interceptor:javax.interceptor-api',
#  'org.apache.openejb:javaee-api',
#  'javax.ejb:javax.ejb-api',
#  'org.eclipse.persistence:eclipselink',
#  'org.glassfish.web:el-impl',
#  'javax.batch:javax.batch-api',
#  'org.eclipse.persistence:org.eclipse.persistence.jpa.jpql',
#  'org.jboss.spec.javax.faces:jboss-jsf-api_2.3_spec',
#  'org.jboss.spec.javax.servlet:jboss-servlet-api_4.0_spec',
#  'args4j:args4j',
#  'net.sf.jopt-simple:jopt-simple',
#  'com.beust:jcommander',
#  'commons-cli:commons-cli',
#  'info.picocli:picocli',
#  'asm:asm',
#  'javassist:javassist',
#  'org.apache.openejb:asm-finder',
#  'org.ow2.asm:asm',
#  'org.ow2.asm:asm-commons',
#  'org.ow2.asm:asm-debug-all',
#  'asm:asm-all',
#  'org.apache.felix:org.apache.felix.scr.generator',
#  'org.apache.servicemix.bundles:org.apache.servicemix.bundles.asm',
#  'org.glassfish.external:asm-all-repackaged',
#  'org.ow2.asm:asm-all',
#  'org.ow2.asm:asm-analysis',
#  'org.ow2.asm:asm-tree',
#  'org.ow2.asm:asm-util',
#  'cglib:cglib-nodep',
#  'org.javassist:javassist',
#  'jboss:javassist',
#  'org.jboss:javassist',
#  'org.jboss.classfilewriter:jboss-classfilewriter',
#  'org.jboss.forge:forge-javassist',
#  'asm:asm-commons',
#  'org.apache.flink:flink-shaded-asm',
#  'com.jtransc:jtransc-asm',
#  'org.apache.xbean:xbean-asm-shaded',
#  'org.jinq:jinq-asm-rebased',
#  'org.glassfish.hk2.external:asm-repackaged',
#  'org.scannotation:scannotation',
#  'backport-util-concurrent:backport-util-concurrent',
#  'commons-pool:commons-pool',
#  'org.apache.commons:commons-pool2',
#  'concurrent:concurrent',
#  'bcel:bcel',
#  'org.apache.bcel:bcel',
#  'c3p0:c3p0',
#  'com.alibaba:druid',
#  'com.mchange:c3p0',
#  'com.zaxxer:HikariCP',
#  'commons-dbcp:commons-dbcp',
#  'org.hibernate:hibernate-c3p0',
#  'com.jolbox:bonecp',
#  'com.zaxxer:HikariCP-java6',
#  'org.apache.tomcat:tomcat-jdbc',
#  'com.zaxxer:HikariCP-java7',
#  'org.apache.commons:commons-dbcp2',
#  'org.springframework.boot:spring-boot-starter-jdbc',
#  'org.springframework:spring-jdbc',
#  'castor:castor',
#  'org.codehaus.castor:castor',
#  'org.apache.geronimo.bundles:castor',
#  'cglib:cglib',
#  'org.sonatype.sisu.inject:cglib',
#  'ch.qos.logback:logback-access',
#  'org.apache.logging.log4j:log4j-api',
#  'org.apache.logging.log4j:log4j-core',
#  'org.apache.logging.log4j:log4j-jcl',
#  'org.apache.logging.log4j:log4j-slf4j-impl',
#  'ch.qos.logback:logback-classic',
#  'log4j:log4j',
#  'org.slf4j:jcl-over-slf4j',
#  'org.slf4j:log4j-over-slf4j',
#  'org.slf4j:slf4j-api',
#  'org.slf4j:slf4j-jdk14',
#  'org.slf4j:slf4j-log4j12',
#  'org.slf4j:slf4j-nop',
#  'org.slf4j:slf4j-simple',
#  'org.springframework.boot:spring-boot-starter-logging',
#  'ch.qos.logback:logback-core',
#  'org.apache.logging.log4j.adapters:log4j-slf4j-impl',
#  'org.kevoree:org.kevoree.log',
#  'commons-logging:commons-logging',
#  'org.jboss.logging:commons-logging-jboss-logging',
#  'org.ops4j.pax.logging:pax-logging-api',
#  'commons-logging:commons-logging-api',
#  'org.jboss.logging:jboss-logging',
#  'org.jboss.logging:jboss-logging-processor',
#  'org.apache.logging.log4j:log4j-1.2-api',
#  'org.slf4j:slf4j-ext',
#  'org.slf4j:slf4j-jcl',
#  'log4j:apache-log4j-extras',
#  'org.slf4j:jul-to-slf4j',
#  'org.springframework.boot:spring-boot-starter-log4j2',
#  'org.jboss.logmanager:commons-logging-jboss-logmanager',
#  'org.apache.logging.log4j:log4j-jul',
#  'org.apache.logging.log4j:log4j-to-slf4j',
#  'io.airlift:log',
#  'org.jboss.logging:jboss-logging-annotations',
#  'org.jboss.logmanager:jboss-logmanager',
#  'org.apache.logging.log4j:log4j-web',
#  'org.spf4j:spf4j-slf4j-test',
#  'org.springframework.boot:spring-boot-dependencies',
#  'com.alibaba:fastjson',
#  'com.fasterxml.jackson.core:jackson-annotations',
#  'com.fasterxml.jackson.core:jackson-core',
#  'com.fasterxml.jackson.core:jackson-databind',
#  'net.sf.json-lib:json-lib',
#  'org.codehaus.jackson:jackson-core-asl',
#  'org.codehaus.jackson:jackson-mapper-asl',
#  'com.fasterxml.jackson.datatype:jackson-datatype-joda',
#  'com.fasterxml.jackson.jaxrs:jackson-jaxrs-json-provider',
#  'com.fasterxml.jackson:jackson-bom',
#  'com.google.code.gson:gson',
#  'org.apache.geronimo.specs:geronimo-json_1.1_spec',
#  'org.apache.geronimo.specs:geronimo-jsonb_1.0_spec',
#  'org.apache.johnzon:johnzon-jsonb',
#  'org.codehaus.jackson:jackson-jaxrs',
#  'org.codehaus.jackson:jackson-smile',
#  'org.jboss.resteasy:resteasy-jackson-provider',
#  'org.json:json',
#  'org.springframework.boot:spring-boot-starter-json',
#  'org.apache.flink:flink-shaded-jackson',
#  'com.fasterxml.jackson.dataformat:jackson-dataformat-yaml',
#  'org.yaml:snakeyaml',
#  'com.fasterxml.jackson.datatype:jackson-datatype-jdk8',
#  'com.fasterxml.jackson.datatype:jackson-datatype-jsr310',
#  'com.github.joschi.jackson:jackson-datatype-threetenbp',
#  'com.fasterxml.jackson.module:jackson-module-jaxb-annotations',
#  'com.github.cliftonlabs:json-simple',
#  'org.apache.camel:json-simple-ordered',
#  'com.squareup.retrofit2:converter-gson',
#  'com.squareup.retrofit2:converter-scalars',
#  'org.jboss.resteasy:resteasy-jackson2-provider',
#  'com.google.code.svenson:svenson',
#  'com.googlecode.json-simple:json-simple',
#  'com.cedarsoftware:json-io',
#  'net.minidev:json-smart',
#  'com.fasterxml.jackson.dataformat:jackson-dataformat-xml',
#  'com.typesafe:config',
#  'xerces:xercesImpl',
#  'net.sf.flexjson:flexjson',
#  'com.fasterxml.jackson.dataformat:jackson-dataformat-smile',
#  'com.fasterxml.jackson.datatype:jackson-datatype-guava',
#  'com.fasterxml.jackson.datatype:jackson-datatype-json-org',
#  'com.fasterxml.jackson.jaxrs:jackson-jaxrs-base',
#  'com.fasterxml.jackson.jaxrs:jackson-jaxrs-xml-provider',
#  'org.codehaus.jackson:jackson-xc',
#  'org.codehaus.jettison:jettison',
#  'com.tdunning:json',
#  'com.unboundid.components:json',
#  'com.vaadin.external.google:android-json',
#  'org.apache.felix:org.apache.felix.utils',
#  'org.apache.johnzon:johnzon-core',
#  'org.simpleframework:simple-xml',
#  'org.springframework:spring-oxm',
#  'xerces:xerces',
#  'org.opengis.cite.xerces:xercesImpl-xsd11',
#  'edu.stanford.protege:protege-launcher',
#  'com.google.collections:google-collections',
#  'com.google.guava:guava',
#  'com.googlecode.guava-osgi:guava-osgi',
#  'cz.seznam.euphoria:shaded-guava',
#  'org.apache.commons:commons-lang3',
#  'org.glassfish.jersey.bundles.repackaged:jersey-guava',
#  'commons-codec:commons-codec',
#  'commons-collections:commons-collections',
#  'net.sourceforge.collections:collections-generic',
#  'org.apache.commons:commons-collections4',
#  'commons-lang:commons-lang',
#  'org.apache.commons:commons-text',
#  'com.ning:tr13',
#  'org.apache.commons:commons-math',
#  'colt:colt',
#  'com.blazegraph:colt',
#  'org.apache.mahout:mahout-math',
#  'com.101tec:zkclient',
#  'com.github.sgroschupf:zkclient',
#  'org.apache.curator:curator-client',
#  'org.apache.curator:curator-framework',
#  'org.apache.curator:curator-recipes',
#  'com.alibaba:dubbo',
#  'com.caucho:hessian',
#  'org.apache.dubbo:dubbo',
#  'com.carrotsearch:hppc',
#  'it.unimi.dsi:fastutil',
#  'net.openhft:koloboke-api-jdk6-7',
#  'net.openhft:koloboke-api-jdk8',
#  'net.openhft:koloboke-impl-jdk6-7',
#  'net.openhft:koloboke-impl-jdk8',
#  'fastutil:fastutil',
#  'net.sf.trove4j:trove4j',
#  'com.codahale.metrics:metrics-core',
#  'io.dropwizard.metrics:metrics-core',
#  'com.yammer.metrics:metrics-core',
#  'io.dropwizard.metrics:metrics-annotation',
#  'io.dropwizard.metrics:metrics-ganglia',
#  'io.dropwizard.metrics:metrics-jvm',
#  'io.dropwizard.metrics:metrics-servlet',
#  'io.micrometer:micrometer-core',
#  'io.dropwizard.metrics:metrics-graphite',
#  'io.micrometer:micrometer-registry-influx',
#  'io.micrometer:micrometer-registry-prometheus',
#  'io.micrometer:micrometer-spring-legacy',
#  'com.codahale.metrics:metrics-jvm',
#  'com.codahale.metrics:metrics-servlets',
#  'io.prometheus:simpleclient',
#  'com.datastax.cassandra:cassandra-driver-core',
#  'com.datastax.oss:java-driver-query-builder',
#  'com.facebook.presto.cassandra:cassandra-driver',
#  'com.facebook.presto.cassandra:cassandra-server',
#  'info.archinnov:achilles-embedded',
#  'org.apache.ignite:ignite-cassandra-store',
#  'org.codehaus.mojo:cassandra-maven-plugin',
#  'org.hibernate:hibernate-search-elasticsearch',
#  'org.hibernate:hibernate-search-engine',
#  'org.apache.cassandra:cassandra-all',
#  'com.stratio.cassandra:cassandra-all',
#  'com.esotericsoftware.kryo:kryo',
#  'com.esotericsoftware:kryo',
#  'com.esotericsoftware:kryo-shaded',
#  'org.jboss.resteasy:jaxrs-api',
#  'com.google.gwt:gwt-servlet',
#  'org.glassfish.jersey.core:jersey-server',
#  'org.jboss.spec.javax.ws.rs:jboss-jaxrs-api_1.1_spec',
#  'com.sun.jersey.contribs:jersey-multipart',
#  'org.glassfish.jersey.media:jersey-media-multipart',
#  'com.sun.jersey:jersey-bundle',
#  'org.glassfish.jersey.containers:jersey-container-servlet',
#  'org.glassfish.jersey.containers:jersey-container-servlet-core',
#  'org.glassfish.jersey.core:jersey-client',
#  'org.glassfish.jersey.core:jersey-common',
#  'org.glassfish.jersey.ext:jersey-bean-validation',
#  'org.glassfish.jersey.media:jersey-media-json-jackson',
#  'org.glassfish.jersey.test-framework.providers:jersey-test-framework-provider-grizzly2',
#  'com.sun.jersey:jersey-client',
#  'com.sun.jersey:jersey-core',
#  'com.sun.jersey:jersey-json',
#  'org.glassfish.jersey.media:jersey-media-json-jettison',
#  'com.sun.jersey:jersey-server',
#  'com.sun.jersey:jersey-servlet',
#  'javax.annotation:jsr250-api',
#  'org.apache.geronimo.specs:geronimo-annotation_1.0_spec',
#  'org.jboss.spec.javax.annotation:jboss-annotations-api_1.1_spec',
#  'org.jboss.spec.javax.annotation:jboss-annotations-api_1.2_spec',
#  'org.jboss.spec.javax.el:jboss-el-api_3.0_spec',
#  'org.jboss.spec.javax.ws.rs:jboss-jaxrs-api_2.0_spec',
#  'javax.ws.rs:jsr311-api',
#  'org.jboss.spec.javax.servlet:jboss-servlet-api_3.1_spec',
#  'org.jboss.resteasy:resteasy-jaxrs',
#  'org.jboss.resteasy:resteasy-client',
#  'org.jboss.resteasy:resteasy-guice',
#  'org.jboss.resteasy:resteasy-netty4',
#  'org.jboss.spec.javax.ejb:jboss-ejb-api_3.1_spec',
#  'org.jboss.spec.javax.servlet:jboss-servlet-api_3.0_spec',
#  'org.glassfish.jersey.media:jersey-media-jaxb',
#  'org.jboss.spec.javax.faces:jboss-jsf-api_2.2_spec',
#  'io.undertow:undertow-servlet',
#  'io.undertow:undertow-websockets-jsr',
#  'org.jboss.spec.javax.websocket:jboss-websocket-api_1.0_spec',
#  'com.github.ben-manes.caffeine:caffeine',
#  'javax.cache:cache-api',
#  'org.springframework.boot:spring-boot-starter-cache',
#  'net.sf.ehcache:ehcache',
#  'org.ehcache:ehcache',
#  'net.sf.ehcache:ehcache-core',
#  'org.hibernate:hibernate-ehcache',
#  'com.google.android:android',
#  'org.robolectric:android-all',
#  'com.google.android:android-test',
#  'com.google.testing.compile:compile-testing',
#  'org.robolectric:robolectric',
#  'com.google.code.findbugs:annotations',
#  'com.github.spotbugs:spotbugs',
#  'com.github.spotbugs:spotbugs-annotations',
#  'com.github.stephenc.findbugs:findbugs-annotations',
#  'net.jcip:jcip-annotations',
#  'com.google.code.findbugs:jsr305',
#  'com.github.stephenc.jcip:jcip-annotations',
#  'org.checkerframework:checker-compat-qual',
#  'org.checkerframework:checker-qual',
#  'org.jetbrains:annotations',
#  'com.intellij:annotations',
#  'com.google.code.findbugs:findbugs',
#  'com.qulice:qulice-findbugs',
#  'com.squareup.retrofit2:retrofit',
#  'com.google.http-client:google-http-client',
#  'org.apache.httpcomponents:httpclient',
#  'com.squareup.okhttp:okhttp',
#  'com.jcabi:jcabi-http',
#  'com.squareup.okhttp3:okhttp',
#  'com.squareup.okhttp3:okhttp-urlconnection',
#  'commons-httpclient:commons-httpclient',
#  'org.apache.httpcomponents:fluent-hc',
#  'org.apache.httpcomponents:httpcore',
#  'org.apache.httpcomponents:httpmime',
#  'oauth.signpost:signpost-core',
#  'ch.boye.httpclientandroidlib:httpclientandroidlib',
#  'com.networknt:client',
#  'net.ltgt.jaxrs:resteasy-client-okhttp3',
#  'org.apache.httpcomponents.core5:httpcore5',
#  'org.eclipse.jetty:jetty-client',
#  'org.apache.httpcomponents:httpclient-osgi',
#  'org.eclipse.jetty:jetty-server',
#  'com.google.gwt:gwt-user',
#  'org.eclipse.jetty:jetty-servlet',
#  'com.sparkjava:spark-core',
#  'org.eclipse.jetty:jetty-http',
#  'httpunit:httpunit',
#  'net.sourceforge.htmlunit:htmlunit',
#  'org.apache.tomcat.embed:tomcat-embed-core',
#  'org.apache.tomcat.embed:tomcat-embed-logging-juli',
#  'org.apache.tomcat:tomcat-juli',
#  'org.httpunit:httpunit',
#  'javax.servlet:servlet-api',
#  'org.eclipse.jetty.orbit:javax.servlet',
#  'net.htmlparser.jericho:jericho-html',
#  'org.eclipse.jetty:jetty-io',
#  'org.eclipse.jetty:jetty-plus',
#  'org.eclipse.jetty:jetty-webapp',
#  'org.apache.tomcat.embed:tomcat-embed-jasper',
#  'org.apache.tomcat:tomcat-catalina',
#  'org.eclipse.jetty.aggregate:jetty-all',
#  'org.mortbay.jetty:jetty',
#  'org.eclipse.jetty:jetty-jsp',
#  'org.mortbay.jetty:jsp-2.1',
#  'org.mortbay.jetty:jsp-api-2.1',
#  'org.mortbay.jetty:servlet-api-2.5',
#  'org.eclipse.jetty:jetty-servlets',
#  'org.eclipse.jetty:jetty-util',
#  'org.mortbay.jetty:jetty-util',
#  'org.jsoup:jsoup',
#  'org.eclipse.jetty.aggregate:jetty-all-server',
#  'org.eclipse.jetty:jetty-continuation',
#  'org.eclipse.jetty:jetty-deploy',
#  'org.eclipse.jetty:jetty-jmx',
#  'org.eclipse.jetty:jetty-jsp-2.1',
#  'org.eclipse.jetty:jetty-security',
#  'org.eclipse.jetty:jetty-util-ajax',
#  'org.eclipse.jetty:jetty-xml',
#  'org.jboss.errai:errai-cdi-jboss',
#  'org.cometd.java:bayeux-api',
#  'com.google.truth:truth',
#  'org.assertj:assertj-core',
#  'com.googlecode.jmockit:jmockit',
#  'org.jmockit:jmockit',
#  'org.mockito:mockito-core',
#  'com.spotify:hamcrest-optional',
#  'org.hamcrest:hamcrest',
#  'easymock:easymock',
#  'org.easymock:easymock',
#  'org.easymock:easymockclassextension',
#  'jmock:jmock',
#  'org.hamcrest:hamcrest-core',
#  'org.jmock:jmock',
#  'org.jmock:jmock-junit3',
#  'org.jmock:jmock-junit4',
#  'org.jmock:jmock-legacy',
#  'mockit:jmockit',
#  'org.dspace.dependencies.jmockit:dspace-jmockit',
#  'mockobjects:mockobjects-core',
#  'org.mockito:mockito-all',
#  'org.quartz-scheduler:quartz',
#  'org.powermock:powermock-api-mockito',
#  'org.easytesting:fest-assert',
#  'org.easytesting:fest-assert-core',
#  'org.assertj:assertj-assertions-generator',
#  'org.hamcrest:hamcrest-all',
#  'junit:junit-dep',
#  'org.hamcrest:hamcrest-integration',
#  'org.hamcrest:hamcrest-library',
#  'org.hamcrest:java-hamcrest',
#  'org.springframework.boot:spring-boot-starter',
#  'org.xwiki.commons:xwiki-commons-test-component',
#  'org.ldp4j.framework:ldp4j-application-bom',
#  'org.ldp4j.framework:ldp4j-application-data',
#  'org.ldp4j.framework:ldp4j-application-examples',
#  'org.codehaus.sonar:sonar-testing-harness',
#  'org.powermock:powermock-core',
#  'org.powermock:powermock-module-junit4',
#  'org.powermock:powermock-api-easymock',
#  'org.powermock:powermock-api-mockito2',
#  'org.springframework.cloud:spring-cloud-dependencies',
#  'com.thoughtworks.xstream:xstream',
#  'com.sun.xml.bind:jaxb-core',
#  'org.glassfish.jaxb:jaxb-core',
#  'org.glassfish.jaxb:jaxb-runtime',
#  'com.sun.xml.bind:jaxb-impl',
#  'javax.xml:jaxb-impl',
#  'de.ruedigermoeller:fst',
#  'groovy:groovy-all',
#  'org.codehaus.groovy:groovy-all',
#  'javax.xml.bind:jaxb-api',
#  'org.jboss.spec.javax.xml.bind:jboss-jaxb-api_2.2_spec',
#  'org.jboss.spec.javax.xml.bind:jboss-jaxb-api_2.3_spec',
#  'org.apache.xmlbeans:xmlbeans',
#  'org.codehaus.groovy:groovy',
#  'org.codehaus.groovy:groovy-templates',
#  'org.elasticsearch.module:lang-groovy',
#  'org.jbehave:jbehave-groovy',
#  'org.springframework.cloud:spring-cloud-contract-spec',
#  'org.zkoss.zk:zml',
#  'org.zkoss.zk:zuljsp',
#  'xstream:xstream',
#  'com.h2database:h2',
#  'hsqldb:hsqldb',
#  'mysql:mysql-connector-java',
#  'mysql:mysql-connector-mxj',
#  'net.openhft:chronicle-map',
#  'org.hsqldb:hsqldb',
#  'org.ikasan:ikasan-h2-standalone-persistence',
#  'org.xerial:sqlite-jdbc',
#  'postgresql:postgresql',
#  'com.microsoft.sqlserver:mssql-jdbc',
#  'com.oracle:ojdbc14',
#  'org.apache.derby:derby',
#  'org.apache.derby:derbyclient',
#  'org.apache.geronimo.configs:derby',
#  'org.talend.esb:derby-all',
#  'org.wisdom-framework:derby',
#  'org.wisdom-framework:mysql-connector-java',
#  'org.apache.geronimo.specs:geronimo-ws-metadata_2.0_spec',
#  'org.flywaydb:flyway-core',
#  'org.liquibase:liquibase-core',
#  'org.springframework.boot:spring-boot-starter-data-mongodb',
#  'org.jasig.portal:uportal-db',
#  'org.mariadb.jdbc:mariadb-java-client',
#  'org.postgresql:postgresql',
#  'org.mongodb:mongo-java-driver',
#  'io.vertx:vertx-mysql-postgresql-client',
#  'org.ancoron.postgresql:org.postgresql',
#  'org.jumpmind.symmetric.jdbc:postgresql',
#  'com.impossibl.pgjdbc-ng:pgjdbc-ng',
#  'com.hazelcast:hazelcast-client',
#  'org.ehcache.modules:ehcache-core',
#  'org.ehcache.modules:ehcache-impl',
#  'org.ehcache:ehcache-clustered',
#  'com.itextpdf:itextpdf',
#  'com.lowagie:itext',
#  'org.apache.pdfbox:pdfbox',
#  'com.github.librepdf:openpdf',
#  'com.itextpdf:itext-pdfa',
#  'org.xhtmlrenderer:flying-saucer-fop',
#  'org.xhtmlrenderer:flying-saucer-pdf-openpdf',
#  'org.sejda:sambox',
#  'pdfbox:pdfbox',
#  'com.jayway.awaitility:awaitility',
#  'org.awaitility:awaitility',
#  'com.jayway.jsonpath:json-path',
#  'com.jsoniter:jsoniter',
#  'io.rest-assured:json-path',
#  'com.jayway.restassured:rest-assured',
#  'io.rest-assured:json-schema-validator',
#  'io.rest-assured:rest-assured',
#  'io.rest-assured:spring-mock-mvc',
#  'org.glassfish.jersey.test-framework.providers:jersey-test-framework-provider-jetty',
#  'org.springframework.boot:spring-boot-test',
#  'org.springframework.boot:spring-boot-test-autoconfigure',
#  'org.springframework:spring-test',
#  'org.junit.platform:junit-platform-commons',
#  'com.jcraft:jsch',
#  'org.jclouds.driver:jclouds-sshj',
#  'com.lmax:disruptor',
#  'com.googlecode.disruptor:disruptor',
#  'com.netflix.hystrix:hystrix-core',
#  'org.springframework.cloud:spring-cloud-starter-netflix-hystrix',
#  'com.ning:async-http-client',
#  'io.vertx:vertx-core',
#  'org.asynchttpclient:async-http-client',
#  'io.netty:netty',
#  'org.jboss.netty:netty',
#  'io.netty:netty-all',
#  'de.ruedigermoeller:netty2go',
#  'org.apache.activemq:activemq-core',
#  'org.apache.flink:flink-shaded-netty',
#  'org.apache.hbase.thirdparty:hbase-shaded-netty',
#  'org.fusesource.stompjms:stompjms-client',
#  'org.apache.httpcomponents:httpcore-nio',
#  'org.eclipse.jetty:jetty-annotations',
#  'org.eclipse.jetty.websocket:websocket-server',
#  'io.netty:netty-handler',
#  'org.eclipse.jetty.websocket:websocket-api',
#  'org.eclipse.jetty.websocket:websocket-common',
#  'com.rabbitmq:amqp-client',
#  'org.springframework.amqp:spring-rabbit',
#  'com.sun.faces:jsf-api',
#  'javax.faces:jsf-api',
#  'org.glassfish:javax.faces',
#  'org.jboss.spec.javax.faces:jboss-jsf-api_2.0_spec',
#  'org.jboss.spec.javax.resource:jboss-connector-api_1.6_spec',
#  'org.jboss.spec.javax.xml.rpc:jboss-jaxrpc-api_1.1_spec',
#  'org.richfaces:richfaces',
#  'com.sun.faces:jsf-impl',
#  'org.jboss.spec.javax.faces:jboss-jsf-api_2.1_spec',
#  'ru.yandex.qatools.properties:properties-loader',
#  'ru.qatools.commons:properties',
#  'xmlunit:xmlunit',
#  'org.xmlunit:xmlunit-core',
#  'org.xmlunit:xmlunit-legacy',
#  'com.sun.xml.bind:jaxb-xjc',
#  'org.glassfish.jaxb:jaxb-xjc',
#  'com.vividsolutions:jts',
#  'org.locationtech.jts:jts-core',
#  'commons-beanutils:commons-beanutils',
#  'org.apache.servicemix.bundles:org.apache.servicemix.bundles.commons-beanutils',
#  'commons-configuration:commons-configuration',
#  'org.apache.commons:commons-configuration2',
#  'commons-digester:commons-digester',
#  'org.apache.commons:commons-digester3',
#  'dom4j:dom4j',
#  'jaxen:jaxen',
#  'org.dom4j:dom4j',
#  'org.jdom:jdom',
#  'org.jdom:jdom2',
#  'com.sun.xml.stream.buffer:streambuffer',
#  'jdom:jdom',
#  'org.jvnet.staxex:stax-ex',
#  'org.xmlunit:xmlunit-matchers',
#  'org.apache.servicemix.bundles:org.apache.servicemix.bundles.jdom',
#  'rome:rome',
#  'com.rometools:rome',
#  'xom:xom',
#  'dumbster:dumbster',
#  'com.github.kirviq:dumbster',
#  'org.subethamail:subethasmtp-wiser',
#  'freemarker:freemarker',
#  'org.freemarker:freemarker',
#  'org.apache.velocity:velocity',
#  'com.alibaba.boot:velocity-spring-boot-starter',
#  'org.mvel:mvel2',
#  'com.github.spullara.mustache.java:compiler',
#  'velocity:velocity',
#  'org.apache.velocity:velocity-tools',
#  'xpp3:xpp3',
#  'org.ogce:xpp3',
#  'info.cukes:cucumber-java',
#  'io.cucumber:cucumber-java',
#  'io.cucumber:cucumber-java8',
#  'info.cukes:cucumber-junit',
#  'io.cucumber:cucumber-junit',
#  'io.grpc:grpc-protobuf',
#  'com.google.protobuf:protobuf-java',
#  'io.reactivex:rxjava',
#  'io.reactivex.rxjava2:rxjava',
#  'org.reactivestreams:reactive-streams',
#  'io.springfox:springfox-swagger-ui',
#  'com.github.xiaoymin:swagger-bootstrap-ui',
#  'io.swagger:swagger-annotations',
#  'io.swagger.core.v3:swagger-annotations',
#  'io.undertow:undertow-core',
#  'org.glassfish.jersey.containers:jersey-container-grizzly2-http',
#  'itsnat:itsnat',
#  'com.vaadin:vaadin',
#  'jasperreports:jasperreports',
#  'net.sf.jasperreports:jasperreports',
#  'javax.activation:activation',
#  'com.sun.activation:javax.activation',
#  'org.apache.geronimo.specs:geronimo-activation_1.1_spec',
#  'javax.activation:javax.activation-api',
#  'javax.mail:javax.mail-api',
#  'com.sun.mail:javax.mail',
#  'javax.mail:mail',
#  'org.apache.geronimo.specs:geronimo-javamail_1.4_spec',
#  'javax.el:el-api',
#  'org.apache.tomcat:tomcat-el-api',
#  'org.jboss.spec.javax.el:jboss-el-api_2.2_spec',
#  'javax.servlet:javax.servlet-api',
#  'javax.servlet.jsp:javax.servlet.jsp-api',
#  'jakarta.servlet:jakarta.servlet-api',
#  'org.apache.tomcat:tomcat-servlet-api',
#  'javax.servlet:jsp-api',
#  'javax.servlet.jsp:jsp-api',
#  'org.apache.tomcat:tomcat-jsp-api',
#  'javax:javaee-web-api',
#  'rhino:js',
#  'org.mozilla:rhino',
#  'javax.servlet:jstl',
#  'javax.servlet.jsp.jstl:javax.servlet.jsp.jstl-api',
#  'javax.servlet.jsp.jstl:jstl-api',
#  'jstl:jstl',
#  'org.apache.taglibs:taglibs-standard-jstlel',
#  'org.glassfish.web:jstl-impl',
#  'org.jboss.spec.javax.servlet.jstl:jboss-jstl-api_1.2_spec',
#  'taglibs:standard',
#  'org.apache.taglibs:taglibs-standard-impl',
#  'org.apache.taglibs:taglibs-standard-spec',
#  'org.hibernate:hibernate-validator',
#  'org.hibernate.validator:hibernate-validator',
#  'org.mybatis:mybatis',
#  'org.mybatis:mybatis-spring',
#  'org.springframework.boot:spring-boot-starter-data-jpa',
#  'org.mybatis.spring.boot:mybatis-spring-boot-starter',
#  'com.baomidou:mybatis-plus-boot-starter',
#  'com.baomidou:mybatis-plus-generator',
#  'tk.mybatis:mapper-spring-boot-starter',
#  'com.baomidou:mybatis-plus-extension',
#  'org.mybatis.generator:mybatis-generator-core',
#  'com.github.pagehelper:pagehelper',
#  'tk.mybatis:mapper',
#  'org.springframework.data:spring-data-jpa',
#  'javax.websocket:javax.websocket-api',
#  'org.eclipse.jetty.websocket:javax-websocket-server-impl',
#  'org.eclipse.jetty.websocket:websocket-client',
#  'javax.xml.ws:jaxws-api',
#  'org.apache.geronimo.specs:geronimo-jaxws_2.1_spec',
#  'jfree:jfreechart',
#  'org.jfree:jfreechart',
#  'jline:jline',
#  'net.sourceforge.jline:jline',
#  'org.fusesource.jansi:jansi',
#  'org.jboss.jreadline:jreadline',
#  'org.jline:jline',
#  'org.jline:jline-builtins',
#  'org.jline:jline-reader',
#  'org.jline:jline-terminal',
#  'org.jline:jline-terminal-jansi',
#  'org.jline:jline-terminal-jna',
#  'org.sonatype.jline:jline',
#  'org.apache.karaf.shell:org.apache.karaf.shell.console',
#  'joda-time:joda-time',
#  'org.threeten:threetenbp',
#  'junit:junit',
#  'org.junit.jupiter:junit-jupiter',
#  'org.junit.jupiter:junit-jupiter-api',
#  'org.junit.jupiter:junit-jupiter-engine',
#  'org.junit.jupiter:junit-jupiter-migrationsupport',
#  'org.junit.jupiter:junit-jupiter-params',
#  'org.junit.platform:junit-platform-launcher',
#  'org.junit.platform:junit-platform-runner',
#  'org.junit.platform:junit-platform-surefire-provider',
#  'org.junit.vintage:junit-vintage-engine',
#  'org.mockito:mockito-junit-jupiter',
#  'org.openengsb.core:openengsb-core-test',
#  'org.springframework.boot:spring-boot-starter-test',
#  'org.testng:testng',
#  'org.apache.maven.surefire:surefire-junit47',
#  'org.jboss.arquillian.junit:arquillian-junit-container',
#  'org.arquillian.universe:arquillian-junit',
#  'org.jboss.arquillian:arquillian-bom',
#  'org.jboss.arquillian.testng:arquillian-testng-container',
#  'io.ap4k:kubernetes-junit-starter',
#  'io.ap4k:openshift-junit-starter',
#  'org.scalatest:scalatest_2.12',
#  'org.junit.platform:junit-platform-console',
#  'org.junit:junit-bom',
#  'io.vertx:vertx-junit5',
#  'com.github.ryanbrainard:richsobjects-api-provider-base-tests',
#  'com.tngtech.java:junit-dataprovider',
#  'org.apache.lucene:lucene-test-framework',
#  'org.jboss.arquillian.ajocado:arquillian-ajocado-junit',
#  'org.jboss.arquillian:arquillian-junit',
#  'jwebunit:jwebunit',
#  'net.sourceforge.jwebunit:jwebunit-htmlunit-plugin',
#  'nekohtml:nekohtml',
#  'net.sourceforge.nekohtml:nekohtml',
#  'nu.validator.htmlparser:htmlparser',
#  'org.htmlparser:htmlparser',
#  'net.sf.opencsv:opencsv',
#  'au.com.bytecode:opencsv',
#  'com.opencsv:opencsv',
#  'org.apache.commons:commons-csv',
#  'net.sf.saxon:saxon',
#  'net.sourceforge.saxon:saxon',
#  'net.sf.saxon:Saxon-HE',
#  'saxon:saxon',
#  'xalan:xalan',
#  'org.antlr:antlr',
#  'org.mvel:mvel14',
#  'org.apache.activemq:activemq-broker',
#  'org.hornetq:hornetq-jms-server',
#  'org.apache.deltaspike.core:deltaspike-core-api',
#  'com.blazebit:blaze-persistence-integration-deltaspike-data-api',
#  'com.blazebit:blaze-persistence-integration-deltaspike-data-impl',
#  'org.apache.deltaspike.distribution:distributions-bom',
#  'org.apache.geronimo.config:geronimo-config-impl',
#  'org.apache.deltaspike.core:deltaspike-core-impl',
#  'org.apache.hbase:hbase',
#  'co.cask.hbase:hbase',
#  'org.apache.hbase:hbase-client',
#  'com.google.cloud.bigtable:bigtable-hbase-1.x',
#  'org.apache.atlas:atlas-hbase-client-shaded',
#  'org.apache.atlas:atlas-hbase-server-shaded',
#  'org.apache.hbase:hbase-server',
#  'org.apache.kafka:kafka_2.10',
#  'org.springframework.kafka:spring-kafka',
#  'org.apache.kafka:kafka_2.11',
#  'org.apache.kafka:kafka-clients',
#  'com.sun.jersey.contribs:jersey-spring',
#  'org.glassfish.jersey.ext:jersey-spring3',
#  'org.glassfish.jersey.ext:jersey-spring4',
#  'org.springframework:spring-webmvc',
#  'org.glassfish.jersey.inject:jersey-hk2',
#  'io.dropwizard:dropwizard-core',
#  'org.springframework.boot:spring-boot-starter-web',
#  'org.springframework:spring-web',
#  'org.apache.lucene:lucene-core',
#  'org.apache.servicemix.bundles:org.apache.servicemix.bundles.lucene',
#  'org.apache.solr:solr',
#  'org.elasticsearch:elasticsearch',
#  'org.apache.solr:solr-core',
#  'org.apache.solr:solr-solrj',
#  'org.elasticsearch.client:elasticsearch-rest-high-level-client',
#  'org.elasticsearch.client:rest',
#  'org.elasticsearch.client:transport',
#  'org.springframework.boot:spring-boot-starter-data-elasticsearch',
#  'com.fasterxml.jackson.dataformat:jackson-dataformat-cbor',
#  'org.springframework.boot:spring-boot-devtools',
#  'org.springframework.boot:spring-boot-starter-tomcat',
#  'org.hibernate:hibernate-entitymanager',
#  'org.apache.openjpa:openjpa',
#  'org.springframework.boot:spring-boot-starter-thymeleaf',
#  'org.thymeleaf.extras:thymeleaf-extras-springsecurity4',
#  'org.thymeleaf:thymeleaf',
#  'org.thymeleaf:thymeleaf-spring4',
#  'org.springframework.cloud:spring-cloud-starter-gateway',
#  'org.springframework.boot:spring-boot-starter-websocket',
#  'org.springframework:spring-messaging',
#  'org.springframework:spring-websocket',
#  'org.apache.mahout:mahout-core',
#  'com.tdunning:t-digest',
#  'org.apache.maven:maven-aether-provider',
#  'org.apache.maven.resolver:maven-resolver-api',
#  'org.apache.maven.resolver:maven-resolver-connector-basic',
#  'org.apache.maven.resolver:maven-resolver-impl',
#  'org.apache.maven.resolver:maven-resolver-spi',
#  'org.apache.maven.resolver:maven-resolver-transport-file',
#  'org.apache.maven.resolver:maven-resolver-transport-http',
#  'org.apache.maven.resolver:maven-resolver-transport-wagon',
#  'org.apache.maven.resolver:maven-resolver-util',
#  'org.eclipse.aether:aether-api',
#  'org.jboss.shrinkwrap.resolver:shrinkwrap-resolver-impl-maven',
#  'org.eclipse.aether:aether-connector-file',
#  'org.eclipse.aether:aether-connector-wagon',
#  'org.eclipse.aether:aether-impl',
#  'org.eclipse.aether:aether-transport-file',
#  'org.eclipse.aether:aether-transport-http',
#  'org.apache.maven:maven-artifact',
#  'org.apache.maven.artifact:maven-artifact',
#  'org.beanshell:bsh',
#  'org.apache-extras.beanshell:bsh',
#  'org.bushe:eventbus',
#  'org.sejda:eventstudio',
#  'org.codehaus.woodstox:stax2-api',
#  'org.jberet:jberet-rest-api',
#  'org.codehaus.woodstox:woodstox-core-asl',
#  'com.fasterxml.woodstox:woodstox-core',
#  'org.codehaus.woodstox:wstx-asl',
#  'org.apache.servicemix.bundles:org.apache.servicemix.bundles.woodstox',
#  'stax:stax-api',
#  'javax.xml.stream:stax-api',
#  'org.apache.geronimo.specs:geronimo-stax-api_1.0_spec',
#  'woodstox:wstx-asl',
#  'com.sun.enterprise:stax-osgi',
#  'org.eclipse.jdt.core.compiler:ecj',
#  'org.eclipse.jdt:ecj',
#  'org.hibernate:hibernate-annotations',
#  'org.hibernate.common:hibernate-commons-annotations',
#  'org.hibernate:hibernate-commons-annotations',
#  'org.infinispan:infinispan-core',
#  'org.jboss.as:jboss-as-clustering',
#  'org.jboss.as:jboss-as-clustering-infinispan',
#  'org.modeshape:modeshape-jcr-api',
#  'org.jboss.as:jboss-as-arquillian-container-managed',
#  'org.wildfly.arquillian:wildfly-arquillian-container-managed',
#  'org.wildfly:wildfly-arquillian-container-managed',
#  'org.jboss.shrinkwrap:shrinkwrap-api',
#  'com.google.jimfs:jimfs',
#  'org.jboss.as:jboss-as-transactions',
#  'org.jboss.shrinkwrap.descriptors:shrinkwrap-descriptors-bom',
#  'org.jboss.shrinkwrap.resolver:shrinkwrap-resolver-depchain',
#  'org.jboss.weld:weld-core',
#  'org.jboss.weld.se:weld-se-core',
#  'org.jgrapht:jgrapht-core',
#  'org.aksw.jena-sparql-api:jena-sparql-api-jgrapht',
#  'org.lwjgl.lwjgl:lwjgl',
#  'org.lwjgl:lwjgl',
#  'org.lwjgl:lwjgl-glfw',
#  'org.lwjgl:lwjgl-openal',
#  'org.lwjgl:lwjgl-opengl',
#  'org.lwjgl:lwjgl-platform',
#  'org.neo4j:neo4j',
#  'com.buschmais.xo:xo.neo4j.api',
#  'org.neo4j.doc:neo4j-cypher-docs-parent',
#  'org.neo4j.doc:neo4j-cypher-refcard-tests',
#  'org.neo4j.doc:neo4j-manual',
#  'org.neo4j.doc:neo4j-manual-contents',
#  'org.neo4j.test:neo4j-harness',
#  'org.osgi:org.osgi.core',
#  'org.apache.felix:org.apache.felix.framework',
#  'org.apache.karaf:org.apache.karaf.main',
#  'org.projectlombok:lombok',
#  'org.jetbrains.kotlin:kotlin-stdlib',
#  'org.jetbrains.kotlin:kotlin-stdlib-jdk8',
#  'org.jetbrains.kotlin:kotlin-test',
#  'org.reflections:reflections',
#  'com.puppycrawl.tools:checkstyle',
#  'eu.infomas:annotation-detector',
#  'io.github.lukehutch:fast-classpath-scanner',
#  'org.scribe:scribe',
#  'com.github.scribejava:scribejava-apis',
#  'com.github.scribejava:scribejava-core',
#  'org.seleniumhq.selenium:selenium-api',
#  'org.jboss.arquillian.selenium:selenium-bom',
#  'org.seleniumhq.selenium:selenium-java',
#  'org.seleniumhq.selenium:selenium-server',
#  'org.slf4j:slf4j-android',
#  'com.github.tony19:logback-android-classic',
#  'org.springframework.boot:spring-boot-starter-amqp',
#  'org.springframework.cloud:spring-cloud-starter-stream-rabbit',
#  'org.springframework.boot:spring-boot-starter-data-redis',
#  'org.springframework.data:spring-data-redis',
#  'org.springframework.boot:spring-boot-starter-redis',
#  'redis.clients:jedis',
#  'io.lettuce:lettuce-core',
#  'org.springframework.integration:spring-integration-redis',
#  'org.springframework.boot:spring-boot-starter-aop',
#  'org.springframework:spring-aop',
#  'org.springframework.boot:spring-boot-starter-security',
#  'org.springframework.security:spring-security-config',
#  'org.springframework.hateoas:spring-hateoas',
#  'org.springframework.boot:spring-boot-starter-hateoas',
#  'org.springframework.security.oauth:spring-security-oauth2',
#  'io.jsonwebtoken:jjwt',
#  'org.springframework.cloud:spring-cloud-security',
#  'org.springframework.cloud:spring-cloud-starter-oauth2',
#  'org.swinglabs:swingx',
#  'net.java.dev.glazedlists:glazedlists_java15',
#  'org.swinglabs.swingx:swingx-all',
#  'org.tuckey:urlrewritefilter',
#  'org.ocpsoft.rewrite:rewrite-servlet',
#  'org.webjars:bootstrap',
#  'de.agilecoders.wicket:wicket-bootstrap-core',
#  'org.xerial.snappy:snappy-java',
#  'org.iq80.snappy:snappy']

# %%
from fake_useragent import UserAgent
import time

class QueryException(Exception):
    pass

def get(url: str, headers):
    sleep_time = 2
    tries = 5
    
    try:
        res = requests.get(url, headers)
    except Exception as e:
        print(f'Error: {url}: {e}', file=sys.stderr)
    time.sleep(sleep_time)
    # repeat request if not successful
    while res and res.status_code != 200 and tries > 0:
        print(f'[{altered_name}] Error: {res.status_code} sleep_time={sleep_time} tries={10-tries}', file=sys.stderr)
        try:
            res = requests.get(url, headers)
        except Exception as e:
            print(f'Error: {url}: {e}', file=sys.stderr)
        time.sleep(sleep_time)
        sleep_time *= 2
        tries -= 1
    
    if res.status_code != 200:
        print(res, file=sys.stderr)
        raise QueryException
    
    return res
    

def query_package(package_name: str):
    altered_name = '/'.join(package_name.split(':'))
    url = 'http://mvnrepository.com/artifact/' + altered_name
    ua = UserAgent()
    headers = {
        'User-Agent': ua.random
    }
    res = get(url, headers)
    return res.text

# %%
text = query_package(package_names[1])

# %%
def parse_package(html: str):
    res = {"category":[], "tag":[]}
    soup = BeautifulSoup(text, 'html.parser')
    table = soup.find('table', attrs={'class':'grid'})
#     print(table)
#     rows = table.find_all('tr')
#     for row in rows:
#         cols = row.find('td')
#         print(cols)
#         res["category"] = cols[1]
#         res["tag"] = cols[2]
#     print(res)
    trs = table.findAll('tr')
    for tr in trs:
        if tr.th.text == 'Categories':
            res["category"] = [ele.text.strip() for ele in tr.td]
        if tr.th.text == 'Tags':
            res["tag"] = [ele.text.strip() for ele in tr.td]
    return res

# %%
parse_package(text)
# Out:
# {'category': ['Build Tools'], 'tag': ['apache', 'ant', 'build', 'tools']}

# %%
import time
from tqdm.auto import tqdm

res_all = {}

for package_name in tqdm(package_names):
    try:
        text = query_package(package_name)
    except Exception:
        continue
    res = parse_package(text)
    print(f'[{package_name}]', res)
    res_all[package_name] = res
# Out:
# HBox(children=(FloatProgress(value=0.0, max=904.0), HTML(value='')))
# [ant:ant] {'category': ['Build Tools'], 'tag': ['ant', 'build', 'tools']}
# [org.apache.ant:ant] {'category': ['Build Tools'], 'tag': ['apache', 'ant', 'build', 'tools']}
# [org.apache.ant:ant-apache-regexp] {'category': [], 'tag': ['regexp', 'ant', 'apache']}
# [org.apache.ant:ant-junit] {'category': [], 'tag': ['testing', 'junit', 'ant', 'apache']}
# [org.apache.ant:ant-nodeps] {'category': [], 'tag': ['ant', 'apache']}
# [org.apache.ant:ant-trax] {'category': [], 'tag': ['ant', 'apache']}
# [commons-io:commons-io] {'category': ['I/O Utilities'], 'tag': ['io']}
# [org.apache.commons:commons-io] {'category': ['I/O Utilities'], 'tag': ['apache', 'io', 'commons']}
# [org.codehaus.plexus:plexus-utils] {'category': ['Core Utilities'], 'tag': ['codehaus']}
# [antlr:antlr] {'category': ['Parser Generators'], 'tag': ['parser', 'compiler', 'generator']}
# [org.antlr:antlr-runtime] {'category': [], 'tag': ['parser', 'compiler', 'runtime']}
# [org.antlr:antlr4-runtime] {'category': [], 'tag': ['parser', 'compiler', 'runtime']}
# [com.tunnelvisionlabs:antlr4-runtime] {'category': [], 'tag': ['parser', 'compiler', 'runtime']}
# [org.codehaus.mojo:javacc-maven-plugin] {'category': ['Maven Plugins'], 'tag': ['plugin', 'compiler', 'parser', 'build', 'build-system', 'maven', 'codehaus']}
# [org.parboiled:parboiled-java] {'category': ['Parser Generators'], 'tag': ['parser', 'generator']}
# [antlr:stringtemplate] {'category': [], 'tag': ['parser', 'compiler']}
# [org.antlr:stringtemplate] {'category': ['Template Engines'], 'tag': ['parser', 'compiler', 'template', 'engine']}
# [aopalliance:aopalliance] {'category': ['Aspect Oriented'], 'tag': ['aop', 'aspect']}
# [com.google.inject.extensions:guice-jmx] {'category': [], 'tag': ['jmx', 'google', 'extension', 'dependency-injection']}
# [com.google.inject:guice] {'category': ['Dependency Injection'], 'tag': ['google', 'dependency-injection']}
# [org.springframework:spring-beans] {'category': ['Dependency Injection'], 'tag': ['beans', 'spring', 'dependency-injection']}
# [org.springframework:spring-context] {'category': ['Dependency Injection'], 'tag': ['spring', 'dependency-injection']}
# [org.springframework:spring-core] {'category': ['Core Utilities'], 'tag': ['spring']}
# [com.google.inject.extensions:guice-assistedinject] {'category': [], 'tag': ['google', 'extension', 'dependency-injection']}
# [com.google.gwt.inject:gin] {'category': ['Dependency Injection'], 'tag': ['gwt', 'ui', 'google', 'dependency-injection']}
# [com.squareup.dagger:dagger] {'category': ['Dependency Injection'], 'tag': ['dependency-injection']}
# [com.squareup.dagger:dagger-compiler] {'category': [], 'tag': ['compiler']}
# [com.google.inject.extensions:guice-multibindings] {'category': [], 'tag': ['google', 'extension', 'dependency-injection']}
# [org.sonatype.sisu:sisu-guice] {'category': [], 'tag': ['dependency-injection']}
# [com.google.inject.extensions:guice-servlet] {'category': [], 'tag': ['google', 'servlet', 'extension', 'dependency-injection']}
# [com.github.rtyley:roboguice-sherlock] {'category': [], 'tag': ['github']}
# [com.google.dagger:dagger] {'category': ['Dependency Injection'], 'tag': ['google', 'dependency-injection']}
# [com.google.dagger:dagger-compiler] {'category': [], 'tag': ['compiler', 'google']}
# [javax.inject:javax.inject] {'category': ['Dependency Injection', 'Java Specifications'], 'tag': ['dependency-injection', 'javax', 'specs', 'standard']}
# [org.roboguice:roboguice] {'category': ['Dependency Injection'], 'tag': ['dependency-injection']}
# [javax.annotation:javax.annotation-api] {'category': ['Java Specifications'], 'tag': ['standard', 'javax', 'annotations', 'api', 'specs']}
# [org.apache.geronimo.specs:geronimo-annotation_1.3_spec] {'category': [], 'tag': ['annotations', 'apache', 'specs']}
# [org.jboss.spec.javax.annotation:jboss-annotations-api_1.3_spec] {'category': [], 'tag': ['annotations', 'jboss', 'api']}
# [javax.el:javax.el-api] {'category': ['Expression Languages', 'Java Specifications'], 'tag': ['standard', 'javax', 'language', 'expression', 'api', 'specs']}
# [jakarta.el:jakarta.el-api] {'category': [], 'tag': ['api']}
# [org.glassfish:javax.el] {'category': ['Expression Languages'], 'tag': ['expression', 'language']}
# [javax.enterprise:cdi-api] {'category': ['Dependency Injection', 'Java Specifications'], 'tag': ['standard', 'dependency-injection', 'javax', 'api', 'specs']}
# [jakarta.enterprise:jakarta.enterprise.cdi-api] {'category': [], 'tag': ['api']}
# [org.apache.geronimo.specs:geronimo-atinject_1.0_spec] {'category': ['Dependency Injection'], 'tag': ['apache', 'specs', 'dependency-injection']}
# [org.apache.servicemix.bundles:org.apache.servicemix.bundles.javax-inject] {'category': [], 'tag': ['bundle', 'apache', 'dependency-injection', 'esb']}
# [javax.json:javax.json-api] {'category': ['Java Specifications'], 'tag': ['standard', 'json', 'javax', 'api', 'specs']}
# [jakarta.json:jakarta.json-api] {'category': [], 'tag': ['json', 'api']}
# [javax.json.bind:javax.json.bind-api] {'category': ['Java Specifications'], 'tag': ['binding', 'standard', 'json', 'javax', 'api', 'specs']}
# [org.glassfish:javax.json] {'category': [], 'tag': ['json']}
# [javax.persistence:persistence-api] {'category': ['Java Specifications'], 'tag': ['persistence', 'standard', 'javax', 'api', 'specs']}
# [org.eclipse.persistence:javax.persistence] {'category': ['JPA Implementations'], 'tag': ['persistence', 'eclipse', 'jpa']}
# [org.hibernate.javax.persistence:hibernate-jpa-2.1-api] {'category': [], 'tag': ['persistence', 'jpa', 'hibernate', 'api']}
# [org.hibernate:hibernate-core] {'category': ['Object/Relational Mapping'], 'tag': ['hibernate', 'persistence', 'relational', 'mapping']}
# [jakarta.validation:jakarta.validation-api] {'category': [], 'tag': ['validation', 'api']}
# [javax.transaction:javax.transaction-api] {'category': ['Transaction APIs/Managers', 'Java Specifications'], 'tag': ['standard', 'javax', 'api', 'transaction', 'specs']}
# [org.jboss.spec.javax.transaction:jboss-transaction-api_1.1_spec] {'category': ['Transaction APIs/Managers'], 'tag': ['jboss', 'api', 'transaction']}
# [org.jboss.spec:jboss-javaee-6.0] {'category': [], 'tag': ['javaee', 'jboss']}
# [javax.transaction:jta] {'category': ['Transaction APIs/Managers', 'Java Specifications'], 'tag': ['transaction', 'javax', 'specs', 'standard']}
# [org.apache.geronimo.specs:geronimo-jta_1.1_spec] {'category': ['Transaction APIs/Managers'], 'tag': ['apache', 'transaction', 'specs']}
# [org.jboss.spec.javax.transaction:jboss-transaction-api_1.2_spec] {'category': ['Transaction APIs/Managers'], 'tag': ['jboss', 'api', 'transaction']}
# [javax.validation:validation-api] {'category': ['Validation Frameworks', 'Java Specifications'], 'tag': ['standard', 'javax', 'api', 'specs', 'validation']}
# [javax.ws.rs:javax.ws.rs-api] {'category': ['Java Specifications'], 'tag': ['api', 'javax', 'specs', 'standard']}
# [jakarta.ws.rs:jakarta.ws.rs-api] {'category': [], 'tag': ['api']}
# [org.jboss.spec.javax.ws.rs:jboss-jaxrs-api_2.1_spec] {'category': [], 'tag': ['jboss', 'api', 'rest', 'jaxrs']}

# %%
# save py obj with pickle
import pickle
with open('data/res_all.pkl', 'w') as f:
    pickle.dump(res_all, f)

# %%
# save changes to excel
df = pd.read_excel('data/cls.xlsx')
df = df.rename(columns={'Unnamed: 1': 'package', 0: 'class'})
df2 = df.set_index('package')
df2['category'] = ""
df2['tag'] = ""
df2
# Out:
#                                              class category tag
# package
# ant:ant                                          0
# org.apache.ant:ant                               0
# org.apache.ant:ant-apache-regexp                 0
# org.apache.ant:ant-junit                         0
# org.apache.ant:ant-nodeps                        0
# ...                                            ...      ...  ..
# org.ocpsoft.rewrite:rewrite-servlet            113
# org.webjars:bootstrap                          114
# de.agilecoders.wicket:wicket-bootstrap-core    114
# org.xerial.snappy:snappy-java                  115
# org.iq80.snappy:snappy                         115
#
# [904 rows x 3 columns]

# %%
for key, value in res_all.items():
    if value['category']:
        df2.loc[key, 'category'] = value['category'][0]
    if value['tag']:
        df2.loc[key, 'tag'] = ','.join(value['tag'])
df2.to_excel('data/cluster2.xlsx')
df2
# Out:
#                                              class               category  \
# package
# ant:ant                                          0            Build Tools
# org.apache.ant:ant                               0            Build Tools
# org.apache.ant:ant-apache-regexp                 0
# org.apache.ant:ant-junit                         0
# org.apache.ant:ant-nodeps                        0
# ...                                            ...                    ...
# org.ocpsoft.rewrite:rewrite-servlet            113
# org.webjars:bootstrap                          114             Web Assets
# de.agilecoders.wicket:wicket-bootstrap-core    114
# org.xerial.snappy:snappy-java                  115  Compression Libraries
# org.iq80.snappy:snappy                         115  Compression Libraries
#
#                                                                   tag
# package
# ant:ant                                               ant,build,tools
# org.apache.ant:ant                             apache,ant,build,tools
# org.apache.ant:ant-apache-regexp                    regexp,ant,apache
# org.apache.ant:ant-junit                     testing,junit,ant,apache
# org.apache.ant:ant-nodeps                                  ant,apache
# ...                                                               ...
# org.ocpsoft.rewrite:rewrite-servlet                           servlet
# org.webjars:bootstrap                            web,bootstrap,assets
# de.agilecoders.wicket:wicket-bootstrap-core          wicket,bootstrap
# org.xerial.snappy:snappy-java                             compression
# org.iq80.snappy:snappy                                    compression
#
# [904 rows x 3 columns]
