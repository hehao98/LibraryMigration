# %% [markdown]
# #### GitHub GraphQL API
# Credit: https://gist.github.com/gbaman/b3137e18c739e0cf98539bf4ec4366ad

# %%
import requests
import json
import time
from dateutil.parser import parse
import pandas as pd

headers = {"Authorization": "bearer 84e5886b54c8d2f6040bd90227494ee619cc5b88"}  # Your token here

# %%
def run_query(query): # A simple function to use requests.post to make the API call. Note the json=section.
    request = requests.post('https://api.github.com/graphql', json={'query': query}, headers=headers)
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception("Query failed to run by returning code of {}. {}".format(request.status_code, query))

# %%
# The GraphQL query (with a few aditional bits included) itself defined as a multi-line string.       
query = """
{
  viewer {
    login
  }
  rateLimit {
    limit
    cost
    remaining
    resetAt
  }
}
"""

result = run_query(query) # Execute the query
remaining_rate_limit = result["data"]["rateLimit"]["remaining"] # Drill down the dictionary
print("Remaining rate limit - {}".format(remaining_rate_limit))
# Out:
# Remaining rate limit - 4993

# %% [markdown]
# For each vulnerability: Description, severity, CVE, published date, affected libraries, affected versions

# %%
def gen_query(last_cursor=None):
    insertion = f"after:\"{last_cursor}\"" if last_cursor else ""
    return """
    {
      securityVulnerabilities(ecosystem: MAVEN, orderBy: {field: UPDATED_AT, direction: ASC}, first: 100
    """ + insertion + """
      ) {
        totalCount
        edges {
          node {
            advisory {
              identifiers {
                type
                value
              }
              description
              severity
              summary
              publishedAt
            }
            firstPatchedVersion {
              identifier
            }
            package {
              name
            }
            severity
            updatedAt
            vulnerableVersionRange
          }
          cursor
        }
      }
    }
    """

# %%
gen_query()
# Out:
# '\n    {\n      securityVulnerabilities(ecosystem: MAVEN, orderBy: {field: UPDATED_AT, direction: ASC}, first: 100\n    \n      ) {\n        totalCount\n        edges {\n          node {\n            advisory {\n              identifiers {\n                type\n                value\n              }\n              description\n              severity\n              summary\n              publishedAt\n            }\n            firstPatchedVersion {\n              identifier\n            }\n            package {\n              name\n            }\n            severity\n            updatedAt\n            vulnerableVersionRange\n          }\n          cursor\n        }\n      }\n    }\n    '

# %%
result_raw = run_query(gen_query())
result = result_raw['data']['securityVulnerabilities']['edges']
# Out:
# {'data': {'securityVulnerabilities': {'totalCount': 974,
#    'edges': [{'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-89gc-6cw6-4vch'},
#         {'type': 'CVE', 'value': 'CVE-2016-9177'}],
#        'description': 'Directory traversal vulnerability in Spark 2.5 allows remote attackers to read arbitrary files via a .. (dot dot) in the URI.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects com.sparkjava:spark-core',
#        'publishedAt': '2018-10-04T19:53:35Z'},
#       'firstPatchedVersion': {'identifier': '2.5.2'},
#       'package': {'name': 'com.sparkjava:spark-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-04T19:53:22Z',
#       'vulnerableVersionRange': '< 2.5.2'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0wNVQwMzo1MzoyMiswODowMM0EWw=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-2m8h-fgr8-2q9w'},
#         {'type': 'CVE', 'value': 'CVE-2016-9878'}],
#        'description': 'An issue was discovered in Pivotal Spring Framework before 3.2.18, 4.2.x before 4.2.9, and 4.3.x before 4.3.5. Paths provided to the ResourceServlet were not properly sanitized and as a result exposed to directory traversal attacks.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.springframework:spring-core',
#        'publishedAt': '2018-10-04T20:29:55Z'},
#       'firstPatchedVersion': {'identifier': '3.2.18'},
#       'package': {'name': 'org.springframework:spring-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-04T20:29:47Z',
#       'vulnerableVersionRange': '< 3.2.18'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0wNVQwNDoyOTo0NyswODowMM0EXA=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-2m8h-fgr8-2q9w'},
#         {'type': 'CVE', 'value': 'CVE-2016-9878'}],
#        'description': 'An issue was discovered in Pivotal Spring Framework before 3.2.18, 4.2.x before 4.2.9, and 4.3.x before 4.3.5. Paths provided to the ResourceServlet were not properly sanitized and as a result exposed to directory traversal attacks.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.springframework:spring-core',
#        'publishedAt': '2018-10-04T20:29:55Z'},
#       'firstPatchedVersion': {'identifier': '4.2.9'},
#       'package': {'name': 'org.springframework:spring-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-04T20:29:47Z',
#       'vulnerableVersionRange': '>= 4.2.0, < 4.2.9'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0wNVQwNDoyOTo0NyswODowMM0EXQ=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-2m8h-fgr8-2q9w'},
#         {'type': 'CVE', 'value': 'CVE-2016-9878'}],
#        'description': 'An issue was discovered in Pivotal Spring Framework before 3.2.18, 4.2.x before 4.2.9, and 4.3.x before 4.3.5. Paths provided to the ResourceServlet were not properly sanitized and as a result exposed to directory traversal attacks.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.springframework:spring-core',
#        'publishedAt': '2018-10-04T20:29:55Z'},
#       'firstPatchedVersion': {'identifier': '4.3.5'},
#       'package': {'name': 'org.springframework:spring-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-04T20:29:47Z',
#       'vulnerableVersionRange': '>= 4.3.0, < 4.3.5'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0wNVQwNDoyOTo0NyswODowMM0EXg=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-hvpr-9cr6-q5v7'},
#         {'type': 'CVE', 'value': 'CVE-2017-3159'}],
#        'description': "Apache Camel's camel-snakeyaml component is vulnerable to Java object de-serialization vulnerability. De-serializing untrusted data can lead to security flaws.",
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects org.apache.camel:camel-snakeyaml',
#        'publishedAt': '2018-10-16T17:21:42Z'},
#       'firstPatchedVersion': {'identifier': '2.17.5'},
#       'package': {'name': 'org.apache.camel:camel-snakeyaml'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T17:20:38Z',
#       'vulnerableVersionRange': '< 2.17.5'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMToyMDozOCswODowMM0Ejw=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-hvpr-9cr6-q5v7'},
#         {'type': 'CVE', 'value': 'CVE-2017-3159'}],
#        'description': "Apache Camel's camel-snakeyaml component is vulnerable to Java object de-serialization vulnerability. De-serializing untrusted data can lead to security flaws.",
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects org.apache.camel:camel-snakeyaml',
#        'publishedAt': '2018-10-16T17:21:42Z'},
#       'firstPatchedVersion': {'identifier': '2.18.2'},
#       'package': {'name': 'org.apache.camel:camel-snakeyaml'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T17:20:38Z',
#       'vulnerableVersionRange': '>= 2.18.0, < 2.18.2'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMToyMDozOCswODowMM0EkA=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-qxxx-2pp7-5hmx'},
#         {'type': 'CVE', 'value': 'CVE-2017-7525'}],
#        'description': 'A deserialization flaw was discovered in the jackson-databind, versions before 2.6.7.1, 2.7.9.1 and 2.8.9, which could allow an unauthenticated user to perform code execution by sending the maliciously crafted input to the readValue method of the ObjectMapper.',
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects com.fasterxml.jackson.core:jackson-databind',
#        'publishedAt': '2018-10-16T17:21:35Z'},
#       'firstPatchedVersion': {'identifier': '2.6.7.1'},
#       'package': {'name': 'com.fasterxml.jackson.core:jackson-databind'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T17:21:00Z',
#       'vulnerableVersionRange': '< 2.6.7.1'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMToyMTowMCswODowMM0EkQ=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-qxxx-2pp7-5hmx'},
#         {'type': 'CVE', 'value': 'CVE-2017-7525'}],
#        'description': 'A deserialization flaw was discovered in the jackson-databind, versions before 2.6.7.1, 2.7.9.1 and 2.8.9, which could allow an unauthenticated user to perform code execution by sending the maliciously crafted input to the readValue method of the ObjectMapper.',
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects com.fasterxml.jackson.core:jackson-databind',
#        'publishedAt': '2018-10-16T17:21:35Z'},
#       'firstPatchedVersion': {'identifier': '2.7.9.1'},
#       'package': {'name': 'com.fasterxml.jackson.core:jackson-databind'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T17:21:00Z',
#       'vulnerableVersionRange': '>= 2.7.0, < 2.7.9.1'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMToyMTowMCswODowMM0Ekg=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-qxxx-2pp7-5hmx'},
#         {'type': 'CVE', 'value': 'CVE-2017-7525'}],
#        'description': 'A deserialization flaw was discovered in the jackson-databind, versions before 2.6.7.1, 2.7.9.1 and 2.8.9, which could allow an unauthenticated user to perform code execution by sending the maliciously crafted input to the readValue method of the ObjectMapper.',
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects com.fasterxml.jackson.core:jackson-databind',
#        'publishedAt': '2018-10-16T17:21:35Z'},
#       'firstPatchedVersion': {'identifier': '2.8.9'},
#       'package': {'name': 'com.fasterxml.jackson.core:jackson-databind'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T17:21:00Z',
#       'vulnerableVersionRange': '>= 2.8.0, < 2.8.9'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMToyMTowMCswODowMM0Ekw=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-898j-5cc8-cmf5'},
#         {'type': 'CVE', 'value': 'CVE-2018-8008'}],
#        'description': 'Apache Storm version 1.0.6 and earlier, 1.2.1 and earlier, and version 1.1.2 and earlier expose an arbitrary file write vulnerability, that can be achieved using a specially crafted zip archive (affects other archives as well, bzip2, tar, xz, war, cpio, 7z), that holds path traversal filenames. So when the filename gets concatenated to the target extraction directory, the final path ends up outside of the target folder.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.storm:storm-core',
#        'publishedAt': '2018-10-16T17:35:24Z'},
#       'firstPatchedVersion': {'identifier': '1.1.3'},
#       'package': {'name': 'org.apache.storm:storm-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T17:35:19Z',
#       'vulnerableVersionRange': '< 1.1.3'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMTozNToxOSswODowMM0Eng=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-898j-5cc8-cmf5'},
#         {'type': 'CVE', 'value': 'CVE-2018-8008'}],
#        'description': 'Apache Storm version 1.0.6 and earlier, 1.2.1 and earlier, and version 1.1.2 and earlier expose an arbitrary file write vulnerability, that can be achieved using a specially crafted zip archive (affects other archives as well, bzip2, tar, xz, war, cpio, 7z), that holds path traversal filenames. So when the filename gets concatenated to the target extraction directory, the final path ends up outside of the target folder.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.storm:storm-core',
#        'publishedAt': '2018-10-16T17:35:24Z'},
#       'firstPatchedVersion': {'identifier': '1.2.2'},
#       'package': {'name': 'org.apache.storm:storm-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T17:35:19Z',
#       'vulnerableVersionRange': '>= 1.2.0, < 1.2.2'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMTozNToxOSswODowMM0Enw=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-9gcm-f4x3-8jpw'},
#         {'type': 'CVE', 'value': 'CVE-2018-11039'}],
#        'description': 'Spring Framework (versions 5.0.x prior to 5.0.7, versions 4.3.x prior to 4.3.18, and older unsupported versions) allow web applications to change the HTTP request method to any HTTP method (including TRACE) using the HiddenHttpMethodFilter in Spring MVC. If an application has a pre-existing XSS vulnerability, a malicious user (or attacker) can use this filter to escalate to an XST (Cross Site Tracing) attack.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.springframework:spring-core',
#        'publishedAt': '2018-10-16T17:35:54Z'},
#       'firstPatchedVersion': {'identifier': '5.0.7'},
#       'package': {'name': 'org.springframework:spring-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T17:35:45Z',
#       'vulnerableVersionRange': '>= 5.0.0, < 5.0.7'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMTozNTo0NSswODowMM0EoA=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-9gcm-f4x3-8jpw'},
#         {'type': 'CVE', 'value': 'CVE-2018-11039'}],
#        'description': 'Spring Framework (versions 5.0.x prior to 5.0.7, versions 4.3.x prior to 4.3.18, and older unsupported versions) allow web applications to change the HTTP request method to any HTTP method (including TRACE) using the HiddenHttpMethodFilter in Spring MVC. If an application has a pre-existing XSS vulnerability, a malicious user (or attacker) can use this filter to escalate to an XST (Cross Site Tracing) attack.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.springframework:spring-core',
#        'publishedAt': '2018-10-16T17:35:54Z'},
#       'firstPatchedVersion': {'identifier': '4.3.18'},
#       'package': {'name': 'org.springframework:spring-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T17:35:45Z',
#       'vulnerableVersionRange': '>= 4.3.0, < 4.3.18'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMTozNTo0NSswODowMM0EoQ=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-f26x-pr96-vw86'},
#         {'type': 'CVE', 'value': 'CVE-2018-11040'}],
#        'description': 'Spring Framework, versions 5.0.x prior to 5.0.7 and 4.3.x prior to 4.3.18 and older unsupported versions, allows web applications to enable cross-domain requests via JSONP (JSON with Padding) through AbstractJsonpResponseBodyAdvice for REST controllers and MappingJackson2JsonView for browser requests. Both are not enabled by default in Spring Framework nor Spring Boot, however, when MappingJackson2JsonView is configured in an application, JSONP support is automatically ready to use through the "jsonp" and "callback" JSONP parameters, enabling cross-domain requests.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.springframework:spring-core',
#        'publishedAt': '2018-10-16T17:43:45Z'},
#       'firstPatchedVersion': {'identifier': '5.0.7'},
#       'package': {'name': 'org.springframework:spring-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T17:43:34Z',
#       'vulnerableVersionRange': '>= 5.0.0, < 5.0.7'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMTo0MzozNCswODowMM0Eog=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-f26x-pr96-vw86'},
#         {'type': 'CVE', 'value': 'CVE-2018-11040'}],
#        'description': 'Spring Framework, versions 5.0.x prior to 5.0.7 and 4.3.x prior to 4.3.18 and older unsupported versions, allows web applications to enable cross-domain requests via JSONP (JSON with Padding) through AbstractJsonpResponseBodyAdvice for REST controllers and MappingJackson2JsonView for browser requests. Both are not enabled by default in Spring Framework nor Spring Boot, however, when MappingJackson2JsonView is configured in an application, JSONP support is automatically ready to use through the "jsonp" and "callback" JSONP parameters, enabling cross-domain requests.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.springframework:spring-core',
#        'publishedAt': '2018-10-16T17:43:45Z'},
#       'firstPatchedVersion': {'identifier': '4.3.18'},
#       'package': {'name': 'org.springframework:spring-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T17:43:34Z',
#       'vulnerableVersionRange': '>= 4.3.0, < 4.3.18'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMTo0MzozNCswODowMM0Eow=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-mwcx-532g-8pq3'},
#         {'type': 'CVE', 'value': 'CVE-2018-12538'}],
#        'description': "In Eclipse Jetty versions 9.4.0 through 9.4.8, when using the optional Jetty provided FileSessionDataStore for persistent storage of HttpSession details, it is possible for a malicious user to access/hijack other HttpSessions and even delete unmatched HttpSessions present in the FileSystem's storage for the FileSessionDataStore.",
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.eclipse.jetty:jetty-server',
#        'publishedAt': '2018-10-16T17:44:11Z'},
#       'firstPatchedVersion': {'identifier': '9.4.11.v20180605'},
#       'package': {'name': 'org.eclipse.jetty:jetty-server'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T17:44:04Z',
#       'vulnerableVersionRange': '>= 9.4.0, < 9.4.11.v20180605'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMTo0NDowNCswODowMM0EpA=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-xqj7-j8j5-f2xr'},
#         {'type': 'CVE', 'value': 'CVE-2018-1000180'}],
#        'description': 'Bouncy Castle BC 1.54 - 1.59, BC-FJA 1.0.0, BC-FJA 1.0.1 and earlier have a flaw in the Low-level interface to RSA key pair generator, specifically RSA Key Pairs generated in low-level API with added certainty may have less M-R tests than expected. This appears to be fixed in versions BC 1.60 beta 4 and later, BC-FJA 1.0.2 and later.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.bouncycastle:bcprov-jdk14 and org.bouncycastle:bcprov-jdk15',
#        'publishedAt': '2018-10-16T17:44:39Z'},
#       'firstPatchedVersion': {'identifier': '1.60'},
#       'package': {'name': 'org.bouncycastle:bcprov-jdk14'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T17:44:33Z',
#       'vulnerableVersionRange': '< 1.60'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMTo0NDozMyswODowMM0EpQ=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-xqj7-j8j5-f2xr'},
#         {'type': 'CVE', 'value': 'CVE-2018-1000180'}],
#        'description': 'Bouncy Castle BC 1.54 - 1.59, BC-FJA 1.0.0, BC-FJA 1.0.1 and earlier have a flaw in the Low-level interface to RSA key pair generator, specifically RSA Key Pairs generated in low-level API with added certainty may have less M-R tests than expected. This appears to be fixed in versions BC 1.60 beta 4 and later, BC-FJA 1.0.2 and later.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.bouncycastle:bcprov-jdk14 and org.bouncycastle:bcprov-jdk15',
#        'publishedAt': '2018-10-16T17:44:39Z'},
#       'firstPatchedVersion': {'identifier': '1.60'},
#       'package': {'name': 'org.bouncycastle:bcprov-jdk15'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T17:44:33Z',
#       'vulnerableVersionRange': '< 1.60'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMTo0NDozMyswODowMM0Epg=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-cggj-fvv3-cqwv'},
#         {'type': 'CVE', 'value': 'CVE-2018-7489'}],
#        'description': 'FasterXML jackson-databind before 2.8.11.1 and 2.9.x before 2.9.5 allows unauthenticated remote code execution because of an incomplete fix for the CVE-2017-7525 deserialization flaw. This is exploitable by sending maliciously crafted JSON input to the readValue method of the ObjectMapper, bypassing a blacklist that is ineffective if the c3p0 libraries are available in the classpath.',
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects com.fasterxml.jackson.core:jackson-databind',
#        'publishedAt': '2018-10-16T17:45:18Z'},
#       'firstPatchedVersion': {'identifier': '2.8.11.1'},
#       'package': {'name': 'com.fasterxml.jackson.core:jackson-databind'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T17:45:08Z',
#       'vulnerableVersionRange': '< 2.8.11.1'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMTo0NTowOCswODowMM0Epw=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-cggj-fvv3-cqwv'},
#         {'type': 'CVE', 'value': 'CVE-2018-7489'}],
#        'description': 'FasterXML jackson-databind before 2.8.11.1 and 2.9.x before 2.9.5 allows unauthenticated remote code execution because of an incomplete fix for the CVE-2017-7525 deserialization flaw. This is exploitable by sending maliciously crafted JSON input to the readValue method of the ObjectMapper, bypassing a blacklist that is ineffective if the c3p0 libraries are available in the classpath.',
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects com.fasterxml.jackson.core:jackson-databind',
#        'publishedAt': '2018-10-16T17:45:18Z'},
#       'firstPatchedVersion': {'identifier': '2.9.5'},
#       'package': {'name': 'com.fasterxml.jackson.core:jackson-databind'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T17:45:08Z',
#       'vulnerableVersionRange': '>= 2.9.0, < 2.9.5'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMTo0NTowOCswODowMM0EqA=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-38cr-2ph5-frr9'},
#         {'type': 'CVE', 'value': 'CVE-2018-1327'}],
#        'description': 'The Apache Struts REST Plugin is using XStream library which is vulnerable and allow perform a DoS attack when using a malicious request with specially crafted XML payload. Upgrade to the Apache Struts version 2.5.16 and switch to an optional Jackson XML handler as described here http://struts.apache.org/plugins/rest/#custom-contenttypehandlers. Another option is to implement a custom XML handler based on the Jackson XML handler from the Apache Struts 2.5.16.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.struts:struts2-rest-plugin',
#        'publishedAt': '2018-10-16T19:35:26Z'},
#       'firstPatchedVersion': {'identifier': '2.5.16'},
#       'package': {'name': 'org.apache.struts:struts2-rest-plugin'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:35:22Z',
#       'vulnerableVersionRange': '< 2.5.16'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzozNToyMiswODowMM0ErQ=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-8fx9-5hx8-crhm'},
#         {'type': 'CVE', 'value': 'CVE-2017-12611'}],
#        'description': 'In Apache Struts 2.0.1 through 2.3.33 and 2.5 through 2.5.10, using an unintentional expression in a Freemarker tag instead of string literals can lead to a RCE attack.',
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects org.apache.struts:struts2-core',
#        'publishedAt': '2018-10-16T19:35:40Z'},
#       'firstPatchedVersion': {'identifier': '2.3.34'},
#       'package': {'name': 'org.apache.struts:struts2-core'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T19:35:33Z',
#       'vulnerableVersionRange': '>= 2.0.1, <= 2.3.33'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzozNTozMyswODowMM0Erg=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-8fx9-5hx8-crhm'},
#         {'type': 'CVE', 'value': 'CVE-2017-12611'}],
#        'description': 'In Apache Struts 2.0.1 through 2.3.33 and 2.5 through 2.5.10, using an unintentional expression in a Freemarker tag instead of string literals can lead to a RCE attack.',
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects org.apache.struts:struts2-core',
#        'publishedAt': '2018-10-16T19:35:40Z'},
#       'firstPatchedVersion': {'identifier': '2.5.12'},
#       'package': {'name': 'org.apache.struts:struts2-core'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T19:35:33Z',
#       'vulnerableVersionRange': '>= 2.5.0, <= 2.5.10'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzozNTozMyswODowMM0Erw=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-xcrm-qpp8-hcw4'},
#         {'type': 'CVE', 'value': 'CVE-2017-15707'}],
#        'description': 'In Apache Struts 2.5 to 2.5.14, the REST Plugin is using an outdated JSON-lib library which is vulnerable and allow perform a DoS attack using malicious request with specially crafted JSON payload.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.struts:struts2-rest-plugin',
#        'publishedAt': '2018-10-16T19:35:55Z'},
#       'firstPatchedVersion': {'identifier': '2.5.16'},
#       'package': {'name': 'org.apache.struts:struts2-rest-plugin'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:35:51Z',
#       'vulnerableVersionRange': '>= 2.5.0, <= 2.5.14'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzozNTo1MSswODowMM0EsA=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-9gp7-jvm2-r4mx'},
#         {'type': 'CVE', 'value': 'CVE-2017-7672'}],
#        'description': 'If an application allows enter an URL in a form field and built-in URLValidator is used, it is possible to prepare a special URL which will be used to overload server process when performing validation of the URL. Solution is to upgrade to Apache Struts version 2.5.12.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.struts:struts2-core',
#        'publishedAt': '2018-10-16T19:36:43Z'},
#       'firstPatchedVersion': {'identifier': '2.5.12'},
#       'package': {'name': 'org.apache.struts:struts2-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:36:38Z',
#       'vulnerableVersionRange': '>= 2.5.0, < 2.5.12'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzozNjozOCswODowMM0EsQ=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-8mr5-h28g-36qx'},
#         {'type': 'CVE', 'value': 'CVE-2017-9787'}],
#        'description': 'When using a Spring AOP functionality to secure Struts actions it is possible to perform a DoS attack. Solution is to upgrade to Apache Struts version 2.5.12 or 2.3.33.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.struts:struts2-core',
#        'publishedAt': '2018-10-16T19:37:07Z'},
#       'firstPatchedVersion': {'identifier': '2.3.33'},
#       'package': {'name': 'org.apache.struts:struts2-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:37:02Z',
#       'vulnerableVersionRange': '< 2.3.33'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzozNzowMiswODowMM0Esg=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-8mr5-h28g-36qx'},
#         {'type': 'CVE', 'value': 'CVE-2017-9787'}],
#        'description': 'When using a Spring AOP functionality to secure Struts actions it is possible to perform a DoS attack. Solution is to upgrade to Apache Struts version 2.5.12 or 2.3.33.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.struts:struts2-core',
#        'publishedAt': '2018-10-16T19:37:07Z'},
#       'firstPatchedVersion': {'identifier': '2.5.12'},
#       'package': {'name': 'org.apache.struts:struts2-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:37:02Z',
#       'vulnerableVersionRange': '>= 2.5.0, < 2.5.12'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzozNzowMiswODowMM0Esw=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-vwxj-6m5m-rrvh'},
#         {'type': 'CVE', 'value': 'CVE-2017-9793'}],
#        'description': 'The REST Plugin in Apache Struts 2.3.7 through 2.3.33 and 2.5 through 2.5.12 is using an outdated XStream library which is vulnerable and allow perform a DoS attack using malicious request with specially crafted XML payload.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.struts:struts2-rest-plugin',
#        'publishedAt': '2018-10-16T19:37:22Z'},
#       'firstPatchedVersion': {'identifier': '2.5.13'},
#       'package': {'name': 'org.apache.struts:struts2-rest-plugin'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:37:17Z',
#       'vulnerableVersionRange': '>= 2.5.0, <= 2.5.12'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzozNzoxNyswODowMM0EtQ=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-x5x7-3v85-wpc4'},
#         {'type': 'CVE', 'value': 'CVE-2017-9804'}],
#        'description': 'In Apache Struts 2.3.7 through 2.3.33 and 2.5 through 2.5.12, if an application allows entering a URL in a form field and built-in URLValidator is used, it is possible to prepare a special URL which will be used to overload server process when performing validation of the URL.  NOTE: this vulnerability exists because of an incomplete fix for S2-047 / CVE-2017-7672.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.struts:struts2-core',
#        'publishedAt': '2018-10-16T19:37:33Z'},
#       'firstPatchedVersion': {'identifier': '2.3.34'},
#       'package': {'name': 'org.apache.struts:struts2-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:37:29Z',
#       'vulnerableVersionRange': '>= 2.3.7, <= 2.3.33'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzozNzoyOSswODowMM0Etg=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-x5x7-3v85-wpc4'},
#         {'type': 'CVE', 'value': 'CVE-2017-9804'}],
#        'description': 'In Apache Struts 2.3.7 through 2.3.33 and 2.5 through 2.5.12, if an application allows entering a URL in a form field and built-in URLValidator is used, it is possible to prepare a special URL which will be used to overload server process when performing validation of the URL.  NOTE: this vulnerability exists because of an incomplete fix for S2-047 / CVE-2017-7672.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.struts:struts2-core',
#        'publishedAt': '2018-10-16T19:37:33Z'},
#       'firstPatchedVersion': {'identifier': '2.5.13'},
#       'package': {'name': 'org.apache.struts:struts2-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:37:29Z',
#       'vulnerableVersionRange': '>= 2.5.0, <= 2.5.12'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzozNzoyOSswODowMM0Etw=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-gg9m-fj3v-r58c'},
#         {'type': 'CVE', 'value': 'CVE-2017-9805'}],
#        'description': 'The REST Plugin in Apache Struts 2.1.2 through 2.3.x before 2.3.34 and 2.5.x before 2.5.13 uses an XStreamHandler with an instance of XStream for deserialization without any type filtering, which can lead to Remote Code Execution when deserializing XML payloads.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.struts:struts2-rest-plugin',
#        'publishedAt': '2018-10-16T19:37:56Z'},
#       'firstPatchedVersion': {'identifier': '2.3.34'},
#       'package': {'name': 'org.apache.struts:struts2-rest-plugin'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:37:51Z',
#       'vulnerableVersionRange': '< 2.3.34'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzozNzo1MSswODowMM0EuA=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-gg9m-fj3v-r58c'},
#         {'type': 'CVE', 'value': 'CVE-2017-9805'}],
#        'description': 'The REST Plugin in Apache Struts 2.1.2 through 2.3.x before 2.3.34 and 2.5.x before 2.5.13 uses an XStreamHandler with an instance of XStream for deserialization without any type filtering, which can lead to Remote Code Execution when deserializing XML payloads.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.struts:struts2-rest-plugin',
#        'publishedAt': '2018-10-16T19:37:56Z'},
#       'firstPatchedVersion': {'identifier': '2.5.13'},
#       'package': {'name': 'org.apache.struts:struts2-rest-plugin'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:37:51Z',
#       'vulnerableVersionRange': '>= 2.5.0, < 2.5.13'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzozNzo1MSswODowMM0EuQ=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-49h4-g8p5-jgq6'},
#         {'type': 'CVE', 'value': 'CVE-2015-5241'}],
#        'description': "After logging into the portal, the logout jsp page redirects the browser back to the login page after. It is feasible for malicious users to redirect the browser to an unintended web page in Apache jUDDI 3.1.2, 3.1.3, 3.1.4, and 3.1.5 when utilizing the portlets based user interface also known as 'Pluto', 'jUDDI Portal', 'UDDI Portal' or 'uddi-console'. User session data, credentials, and auth tokens are cleared before the redirect.",
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.juddi:juddi-client',
#        'publishedAt': '2018-10-16T19:49:32Z'},
#       'firstPatchedVersion': {'identifier': '3.2.0'},
#       'package': {'name': 'org.apache.juddi:juddi-client'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:49:08Z',
#       'vulnerableVersionRange': '>= 3.1.2, <= 3.1.5'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzo0OTowOCswODowMM0Eug=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-q66c-h853-gqw2'},
#         {'type': 'CVE', 'value': 'CVE-2016-4432'}],
#        'description': 'The AMQP 0-8, 0-9, 0-91, and 0-10 connection handling in Apache Qpid Java before 6.0.3 might allow remote attackers to bypass authentication and consequently perform actions via vectors related to connection state logging.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.qpid:qpid-broker-plugins-amqp-0-8-protocol and org.apache.qpid:qpid-broker-plugins-amqp-1-0-protocol',
#        'publishedAt': '2018-10-16T19:49:48Z'},
#       'firstPatchedVersion': {'identifier': '6.0.3'},
#       'package': {'name': 'org.apache.qpid:qpid-broker-plugins-amqp-0-8-protocol'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:49:43Z',
#       'vulnerableVersionRange': '< 6.0.3'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzo0OTo0MyswODowMM0Euw=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-q66c-h853-gqw2'},
#         {'type': 'CVE', 'value': 'CVE-2016-4432'}],
#        'description': 'The AMQP 0-8, 0-9, 0-91, and 0-10 connection handling in Apache Qpid Java before 6.0.3 might allow remote attackers to bypass authentication and consequently perform actions via vectors related to connection state logging.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.qpid:qpid-broker-plugins-amqp-0-8-protocol and org.apache.qpid:qpid-broker-plugins-amqp-1-0-protocol',
#        'publishedAt': '2018-10-16T19:49:48Z'},
#       'firstPatchedVersion': {'identifier': '6.0.3'},
#       'package': {'name': 'org.apache.qpid:qpid-broker-plugins-amqp-1-0-protocol'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:49:43Z',
#       'vulnerableVersionRange': '< 6.0.3'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzo0OTo0MyswODowMM0EvA=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-jj9h-mwhq-8vhm'},
#         {'type': 'CVE', 'value': 'CVE-2016-3094'}],
#        'description': 'PlainSaslServer.java in Apache Qpid Java before 6.0.3, when the broker is configured to allow plaintext passwords, allows remote attackers to cause a denial of service (broker termination) via a crafted authentication attempt, which triggers an uncaught exception.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.qpid:qpid-broker',
#        'publishedAt': '2018-10-16T19:50:13Z'},
#       'firstPatchedVersion': {'identifier': '6.0.3'},
#       'package': {'name': 'org.apache.qpid:qpid-broker'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:50:04Z',
#       'vulnerableVersionRange': '< 6.0.3'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzo1MDowNCswODowMM0EvQ=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-f5cf-f7px-xpmh'},
#         {'type': 'CVE', 'value': 'CVE-2016-2166'}],
#        'description': 'The (1) proton.reactor.Connector, (2) proton.reactor.Container, and (3) proton.utils.BlockingConnection classes in Apache Qpid Proton before 0.12.1 improperly use an unencrypted connection for an amqps URI scheme when SSL support is unavailable, which might allow man-in-the-middle attackers to obtain sensitive information or modify data via unspecified vectors.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.qpid:proton-j',
#        'publishedAt': '2018-10-16T19:50:27Z'},
#       'firstPatchedVersion': {'identifier': '0.12.1'},
#       'package': {'name': 'org.apache.qpid:proton-j'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:50:22Z',
#       'vulnerableVersionRange': '< 0.12.1'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzo1MDoyMiswODowMM0Evg=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-7xr3-rgwh-pw22'},
#         {'type': 'CVE', 'value': 'CVE-2018-8030'}],
#        'description': 'A Denial of Service vulnerability was found in Apache Qpid Broker-J versions 7.0.0-7.0.4 when AMQP protocols 0-8, 0-9 or 0-91 are used to publish messages with size greater than allowed maximum message size limit (100MB by default). The broker crashes due to the defect. AMQP protocols 0-10 and 1.0 are not affected.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.qpid:apache-qpid-broker-j',
#        'publishedAt': '2018-10-16T19:50:39Z'},
#       'firstPatchedVersion': {'identifier': '7.0.5'},
#       'package': {'name': 'org.apache.qpid:apache-qpid-broker-j'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T19:50:35Z',
#       'vulnerableVersionRange': '>= 7.0.0, < 7.0.5'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwMzo1MDozNSswODowMM0Evw=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-8p83-68cw-943f'},
#         {'type': 'CVE', 'value': 'CVE-2017-7686'}],
#        'description': 'Apache Ignite 1.0.0-RC3 to 2.0 uses an update notifier component to update the users about new project releases that include additional functionality, bug fixes and performance improvements. To do that the component communicates to an external PHP server (http://ignite.run) where it needs to send some system properties like Apache Ignite or Java version. Some of the properties might contain user sensitive information.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.ignite:ignite-core',
#        'publishedAt': '2018-10-16T20:53:20Z'},
#       'firstPatchedVersion': {'identifier': '2.1'},
#       'package': {'name': 'org.apache.ignite:ignite-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T20:53:15Z',
#       'vulnerableVersionRange': '< 2.1'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwNDo1MzoxNSswODowMM0E5w=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-8qfc-cvjp-mgpq'},
#         {'type': 'CVE', 'value': 'CVE-2016-6805'}],
#        'description': 'Apache Ignite before 1.9 allows man-in-the-middle attackers to read arbitrary files via XXE in modified update-notifier documents.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.ignite:ignite-core',
#        'publishedAt': '2018-10-16T20:53:31Z'},
#       'firstPatchedVersion': {'identifier': '1.9'},
#       'package': {'name': 'org.apache.ignite:ignite-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T20:53:27Z',
#       'vulnerableVersionRange': '< 1.9'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwNDo1MzoyNyswODowMM0E6A=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-chp4-rv79-68j3'},
#         {'type': 'CVE', 'value': 'CVE-2018-1295'}],
#        'description': 'In Apache Ignite 2.3 or earlier, the serialization mechanism does not have a list of classes allowed for serialization/deserialization, which makes it possible to run arbitrary code when 3-rd party vulnerable classes are present in Ignite classpath. The vulnerability can be exploited if the one sends a specially prepared form of a serialized object to one of the deserialization endpoints of some Ignite components - discovery SPI, Ignite persistence, Memcached endpoint, socket steamer.',
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects org.apache.ignite:ignite-core',
#        'publishedAt': '2018-10-16T20:53:44Z'},
#       'firstPatchedVersion': {'identifier': '2.4'},
#       'package': {'name': 'org.apache.ignite:ignite-core'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T20:53:40Z',
#       'vulnerableVersionRange': '< 2.4'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwNDo1Mzo0MCswODowMM0E6Q=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-qcjv-wfcg-mmpr'},
#         {'type': 'CVE', 'value': 'CVE-2018-8018'}],
#        'description': 'Apache Ignite 2.5 and earlier serialization mechanism does not have a list of classes allowed for serialization/deserialization, which makes it possible to run arbitrary code when 3-rd party vulnerable classes are present in Ignite classpath. The vulnerability can be exploited if the one sends a specially prepared form of a serialized object to GridClientJdkMarshaller deserialization endpoint.',
#        'severity': 'CRITICAL',
#        'summary': 'Critical severity vulnerability that affects org.apache.ignite:ignite-core',
#        'publishedAt': '2018-10-16T20:53:54Z'},
#       'firstPatchedVersion': {'identifier': '2.6'},
#       'package': {'name': 'org.apache.ignite:ignite-core'},
#       'severity': 'CRITICAL',
#       'updatedAt': '2018-10-16T20:53:50Z',
#       'vulnerableVersionRange': '< 2.6'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwNDo1Mzo1MCswODowMM0E6g=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-vf4q-8mr7-5c5c'},
#         {'type': 'CVE', 'value': 'CVE-2017-12634'}],
#        'description': 'The camel-castor component in Apache Camel 2.x before 2.19.4 and 2.20.x before 2.20.1 is vulnerable to Java object de-serialisation vulnerability. De-serializing untrusted data can lead to security flaws.',
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects org.apache.camel:camel-castor',
#        'publishedAt': '2018-10-16T23:05:58Z'},
#       'firstPatchedVersion': {'identifier': '2.19.4'},
#       'package': {'name': 'org.apache.camel:camel-castor'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T23:05:42Z',
#       'vulnerableVersionRange': '>= 2.0.0, < 2.19.4'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwNzowNTo0MiswODowMM0E6w=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-vf4q-8mr7-5c5c'},
#         {'type': 'CVE', 'value': 'CVE-2017-12634'}],
#        'description': 'The camel-castor component in Apache Camel 2.x before 2.19.4 and 2.20.x before 2.20.1 is vulnerable to Java object de-serialisation vulnerability. De-serializing untrusted data can lead to security flaws.',
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects org.apache.camel:camel-castor',
#        'publishedAt': '2018-10-16T23:05:58Z'},
#       'firstPatchedVersion': {'identifier': '2.20.1'},
#       'package': {'name': 'org.apache.camel:camel-castor'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T23:05:42Z',
#       'vulnerableVersionRange': '= 2.20.0'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwNzowNTo0MiswODowMM0E7A=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-8vfm-4388-6rpc'},
#         {'type': 'CVE', 'value': 'CVE-2018-8027'}],
#        'description': 'Apache Camel 2.20.0 to 2.20.3 and 2.21.0 Core is vulnerable to XXE in XSD validation processor.',
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects org.apache.camel:camel-core',
#        'publishedAt': '2018-10-16T23:06:25Z'},
#       'firstPatchedVersion': {'identifier': '2.20.4'},
#       'package': {'name': 'org.apache.camel:camel-core'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T23:05:49Z',
#       'vulnerableVersionRange': '>= 2.20.0, < 2.20.4'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwNzowNTo0OSswODowMM0E7Q=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-8vfm-4388-6rpc'},
#         {'type': 'CVE', 'value': 'CVE-2018-8027'}],
#        'description': 'Apache Camel 2.20.0 to 2.20.3 and 2.21.0 Core is vulnerable to XXE in XSD validation processor.',
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects org.apache.camel:camel-core',
#        'publishedAt': '2018-10-16T23:06:25Z'},
#       'firstPatchedVersion': {'identifier': '2.21.1'},
#       'package': {'name': 'org.apache.camel:camel-core'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T23:05:49Z',
#       'vulnerableVersionRange': '= 2.21.0'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwNzowNTo0OSswODowMM0E7g=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-jv74-f9pj-xp3f'},
#         {'type': 'CVE', 'value': 'CVE-2018-8041'}],
#        'description': "Apache Camel's Mail 2.20.0 through 2.20.3, 2.21.0 through 2.21.1 and 2.22.0 is vulnerable to path traversal.",
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects org.apache.camel:camel-mail',
#        'publishedAt': '2018-10-16T23:07:57Z'},
#       'firstPatchedVersion': {'identifier': '2.20.4'},
#       'package': {'name': 'org.apache.camel:camel-mail'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T23:07:37Z',
#       'vulnerableVersionRange': '>= 2.20.0, < 2.20.4'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwNzowNzozNyswODowMM0E7w=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-jv74-f9pj-xp3f'},
#         {'type': 'CVE', 'value': 'CVE-2018-8041'}],
#        'description': "Apache Camel's Mail 2.20.0 through 2.20.3, 2.21.0 through 2.21.1 and 2.22.0 is vulnerable to path traversal.",
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects org.apache.camel:camel-mail',
#        'publishedAt': '2018-10-16T23:07:57Z'},
#       'firstPatchedVersion': {'identifier': '2.21.2'},
#       'package': {'name': 'org.apache.camel:camel-mail'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T23:07:37Z',
#       'vulnerableVersionRange': '>= 2.21.0, < 2.21.2'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwNzowNzozNyswODowMM0E8A=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-jv74-f9pj-xp3f'},
#         {'type': 'CVE', 'value': 'CVE-2018-8041'}],
#        'description': "Apache Camel's Mail 2.20.0 through 2.20.3, 2.21.0 through 2.21.1 and 2.22.0 is vulnerable to path traversal.",
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects org.apache.camel:camel-mail',
#        'publishedAt': '2018-10-16T23:07:57Z'},
#       'firstPatchedVersion': {'identifier': '2.22.1'},
#       'package': {'name': 'org.apache.camel:camel-mail'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-16T23:07:37Z',
#       'vulnerableVersionRange': '= 2.22.0'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwNzowNzozNyswODowMM0E8Q=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-3hrc-f439-727g'},
#         {'type': 'CVE', 'value': 'CVE-2015-0263'}],
#        'description': 'XML external entity (XXE) vulnerability in the XML converter setup in converter/jaxp/XmlConverter.java in Apache Camel before 2.13.4 and 2.14.x before 2.14.2 allows remote attackers to read arbitrary files via an external entity in an SAXSource.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.apache.camel:camel-core',
#        'publishedAt': '2018-10-16T23:08:43Z'},
#       'firstPatchedVersion': {'identifier': '2.13.4'},
#       'package': {'name': 'org.apache.camel:camel-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-16T23:08:37Z',
#       'vulnerableVersionRange': '< 2.13.4'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xN1QwNzowODozNyswODowMM0E8g=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-3hrc-f439-727g'},
#         {'type': 'CVE', 'value': 'CVE-2015-0263'}],
# ...
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoxNToyOCswODowMM0FFg=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-45xm-v8gq-7jqx'},
#         {'type': 'CVE', 'value': 'CVE-2018-12541'}],
#        'description': 'In version from 3.0.0 to 3.5.3 of Eclipse Vert.x, the WebSocket HTTP upgrade implementation buffers the full http request before doing the handshake, holding the entire request body in memory. There should be a reasonnable limit (8192 bytes) above which the WebSocket gets an HTTP response with the 413 status code and the connection gets closed.',
#        'severity': 'LOW',
#        'summary': 'Low severity vulnerability that affects io.vertx:vertx-core',
#        'publishedAt': '2018-10-17T16:19:59Z'},
#       'firstPatchedVersion': {'identifier': '3.5.4'},
#       'package': {'name': 'io.vertx:vertx-core'},
#       'severity': 'LOW',
#       'updatedAt': '2018-10-17T16:19:55Z',
#       'vulnerableVersionRange': '>= 3.0.0, < 3.5.4'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoxOTo1NSswODowMM0FFw=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-qh3m-qw6v-qvhg'},
#         {'type': 'CVE', 'value': 'CVE-2018-12544'}],
#        'description': 'In version from 3.5.Beta1 to 3.5.3 of Eclipse Vert.x, the OpenAPI XML type validator creates XML parsers without taking appropriate defense against XML attacks. This mechanism is exclusively when the developer uses the Eclipse Vert.x OpenAPI XML type validator to validate a provided schema.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects io.vertx:vertx-core',
#        'publishedAt': '2018-10-17T16:20:32Z'},
#       'firstPatchedVersion': {'identifier': '3.5.4'},
#       'package': {'name': 'io.vertx:vertx-core'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-17T16:20:25Z',
#       'vulnerableVersionRange': '>= 3.5.0, < 3.5.4'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoyMDoyNSswODowMM0FGA=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-h39x-m55c-v55h'},
#         {'type': 'CVE', 'value': 'CVE-2018-12542'}],
#        'description': "In version from 3.0.0 to 3.5.3 of Eclipse Vert.x, the StaticHandler uses external input to construct a pathname that should be within a restricted directory, but it does not properly neutralize '\\' (forward slashes) sequences that can resolve to a location that is outside of that directory when running on Windows Operating Systems.",
#        'severity': 'LOW',
#        'summary': 'Low severity vulnerability that affects io.vertx:vertx-web',
#        'publishedAt': '2018-10-17T16:20:45Z'},
#       'firstPatchedVersion': {'identifier': '3.5.4'},
#       'package': {'name': 'io.vertx:vertx-web'},
#       'severity': 'LOW',
#       'updatedAt': '2018-10-17T16:20:41Z',
#       'vulnerableVersionRange': '>= 3.0.0, < 3.5.4'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoyMDo0MSswODowMM0FGQ=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-4446-656p-f54g'},
#         {'type': 'CVE', 'value': 'CVE-2018-1000613'}],
#        'description': "Legion of the Bouncy Castle Legion of the Bouncy Castle Java Cryptography APIs version prior to version 1.60 contains a CWE-470: Use of Externally-Controlled Input to Select Classes or Code ('Unsafe Reflection') vulnerability in XMSS/XMSS^MT private key deserialization that can result in Deserializing an XMSS/XMSS^MT private key can result in the execution of unexpected code.. This attack appear to be exploitable via A handcrafted private key can include references to unexpected classes which will be picked up from the class path for the executing application.. This vulnerability appears to have been fixed in 1.60 and later.",
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects org.bouncycastle:bcprov-jdk14 and org.bouncycastle:bcprov-jdk15',
#        'publishedAt': '2018-10-17T16:23:12Z'},
#       'firstPatchedVersion': {'identifier': '1.60'},
#       'package': {'name': 'org.bouncycastle:bcprov-jdk14'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-17T16:23:07Z',
#       'vulnerableVersionRange': '< 1.60'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoyMzowNyswODowMM0FGg=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-4446-656p-f54g'},
#         {'type': 'CVE', 'value': 'CVE-2018-1000613'}],
#        'description': "Legion of the Bouncy Castle Legion of the Bouncy Castle Java Cryptography APIs version prior to version 1.60 contains a CWE-470: Use of Externally-Controlled Input to Select Classes or Code ('Unsafe Reflection') vulnerability in XMSS/XMSS^MT private key deserialization that can result in Deserializing an XMSS/XMSS^MT private key can result in the execution of unexpected code.. This attack appear to be exploitable via A handcrafted private key can include references to unexpected classes which will be picked up from the class path for the executing application.. This vulnerability appears to have been fixed in 1.60 and later.",
#        'severity': 'HIGH',
#        'summary': 'High severity vulnerability that affects org.bouncycastle:bcprov-jdk14 and org.bouncycastle:bcprov-jdk15',
#        'publishedAt': '2018-10-17T16:23:12Z'},
#       'firstPatchedVersion': {'identifier': '1.60'},
#       'package': {'name': 'org.bouncycastle:bcprov-jdk15'},
#       'severity': 'HIGH',
#       'updatedAt': '2018-10-17T16:23:07Z',
#       'vulnerableVersionRange': '< 1.60'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoyMzowNyswODowMM0FGw=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-4vhj-98r6-424h'},
#         {'type': 'CVE', 'value': 'CVE-2016-1000338'}],
#        'description': "In Bouncy Castle JCE Provider version 1.55 and earlier the DSA does not fully validate ASN.1 encoding of signature on verification. It is possible to inject extra elements in the sequence making up the signature and still have it validate, which in some cases may allow the introduction of 'invisible' data into a signed structure.",
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.bouncycastle:bcprov-jdk14 and org.bouncycastle:bcprov-jdk15',
#        'publishedAt': '2018-10-17T16:23:26Z'},
#       'firstPatchedVersion': {'identifier': '1.56'},
#       'package': {'name': 'org.bouncycastle:bcprov-jdk14'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-17T16:23:22Z',
#       'vulnerableVersionRange': '< 1.56'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoyMzoyMiswODowMM0FHA=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-4vhj-98r6-424h'},
#         {'type': 'CVE', 'value': 'CVE-2016-1000338'}],
#        'description': "In Bouncy Castle JCE Provider version 1.55 and earlier the DSA does not fully validate ASN.1 encoding of signature on verification. It is possible to inject extra elements in the sequence making up the signature and still have it validate, which in some cases may allow the introduction of 'invisible' data into a signed structure.",
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.bouncycastle:bcprov-jdk14 and org.bouncycastle:bcprov-jdk15',
#        'publishedAt': '2018-10-17T16:23:26Z'},
#       'firstPatchedVersion': {'identifier': '1.5.6'},
#       'package': {'name': 'org.bouncycastle:bcprov-jdk15'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-17T16:23:22Z',
#       'vulnerableVersionRange': '< 1.5.6'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoyMzoyMiswODowMM0FHQ=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-c8xf-m4ff-jcxj'},
#         {'type': 'CVE', 'value': 'CVE-2016-1000339'}],
#        'description': 'In the Bouncy Castle JCE Provider version 1.55 and earlier the primary engine class used for AES was AESFastEngine. Due to the highly table driven approach used in the algorithm it turns out that if the data channel on the CPU can be monitored the lookup table accesses are sufficient to leak information on the AES key being used. There was also a leak in AESEngine although it was substantially less. AESEngine has been modified to remove any signs of leakage (testing carried out on Intel X86-64) and is now the primary AES class for the BC JCE provider from 1.56. Use of AESFastEngine is now only recommended where otherwise deemed appropriate.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.bouncycastle:bcprov-jdk14 and org.bouncycastle:bcprov-jdk15',
#        'publishedAt': '2018-10-17T16:23:38Z'},
#       'firstPatchedVersion': {'identifier': '1.56'},
#       'package': {'name': 'org.bouncycastle:bcprov-jdk14'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-17T16:23:33Z',
#       'vulnerableVersionRange': '< 1.56'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoyMzozMyswODowMM0FHg=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-c8xf-m4ff-jcxj'},
#         {'type': 'CVE', 'value': 'CVE-2016-1000339'}],
#        'description': 'In the Bouncy Castle JCE Provider version 1.55 and earlier the primary engine class used for AES was AESFastEngine. Due to the highly table driven approach used in the algorithm it turns out that if the data channel on the CPU can be monitored the lookup table accesses are sufficient to leak information on the AES key being used. There was also a leak in AESEngine although it was substantially less. AESEngine has been modified to remove any signs of leakage (testing carried out on Intel X86-64) and is now the primary AES class for the BC JCE provider from 1.56. Use of AESFastEngine is now only recommended where otherwise deemed appropriate.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.bouncycastle:bcprov-jdk14 and org.bouncycastle:bcprov-jdk15',
#        'publishedAt': '2018-10-17T16:23:38Z'},
#       'firstPatchedVersion': {'identifier': '1.56'},
#       'package': {'name': 'org.bouncycastle:bcprov-jdk15'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-17T16:23:33Z',
#       'vulnerableVersionRange': '< 1.56'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoyMzozMyswODowMM0FHw=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-r97x-3g8f-gx3m'},
#         {'type': 'CVE', 'value': 'CVE-2016-1000340'}],
#        'description': 'In the Bouncy Castle JCE Provider versions 1.51 to 1.55, a carry propagation bug was introduced in the implementation of squaring for several raw math classes have been fixed (org.bouncycastle.math.raw.Nat???). These classes are used by our custom elliptic curve implementations (org.bouncycastle.math.ec.custom.**), so there was the possibility of rare (in general usage) spurious calculations for elliptic curve scalar multiplications. Such errors would have been detected with high probability by the output validation for our scalar multipliers.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.bouncycastle:bcprov-jdk14 and org.bouncycastle:bcprov-jdk15',
#        'publishedAt': '2018-10-17T16:23:50Z'},
#       'firstPatchedVersion': {'identifier': '1.56'},
#       'package': {'name': 'org.bouncycastle:bcprov-jdk14'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-17T16:23:46Z',
#       'vulnerableVersionRange': '>= 1.51, < 1.56'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoyMzo0NiswODowMM0FIA=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-r97x-3g8f-gx3m'},
#         {'type': 'CVE', 'value': 'CVE-2016-1000340'}],
#        'description': 'In the Bouncy Castle JCE Provider versions 1.51 to 1.55, a carry propagation bug was introduced in the implementation of squaring for several raw math classes have been fixed (org.bouncycastle.math.raw.Nat???). These classes are used by our custom elliptic curve implementations (org.bouncycastle.math.ec.custom.**), so there was the possibility of rare (in general usage) spurious calculations for elliptic curve scalar multiplications. Such errors would have been detected with high probability by the output validation for our scalar multipliers.',
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.bouncycastle:bcprov-jdk14 and org.bouncycastle:bcprov-jdk15',
#        'publishedAt': '2018-10-17T16:23:50Z'},
#       'firstPatchedVersion': {'identifier': '1.56'},
#       'package': {'name': 'org.bouncycastle:bcprov-jdk15'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-17T16:23:46Z',
#       'vulnerableVersionRange': '>= 1.51, < 1.56'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoyMzo0NiswODowMM0FIQ=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-r9ch-m4fh-fc7q'},
#         {'type': 'CVE', 'value': 'CVE-2016-1000341'}],
#        'description': "In the Bouncy Castle JCE Provider version 1.55 and earlier DSA signature generation is vulnerable to timing attack. Where timings can be closely observed for the generation of signatures, the lack of blinding in 1.55, or earlier, may allow an attacker to gain information about the signature's k value and ultimately the private value as well.",
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.bouncycastle:bcprov-jdk14 and org.bouncycastle:bcprov-jdk15',
#        'publishedAt': '2018-10-17T16:24:00Z'},
#       'firstPatchedVersion': {'identifier': '1.56'},
#       'package': {'name': 'org.bouncycastle:bcprov-jdk14'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-17T16:23:55Z',
#       'vulnerableVersionRange': '< 1.56'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoyMzo1NSswODowMM0FIg=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-r9ch-m4fh-fc7q'},
#         {'type': 'CVE', 'value': 'CVE-2016-1000341'}],
#        'description': "In the Bouncy Castle JCE Provider version 1.55 and earlier DSA signature generation is vulnerable to timing attack. Where timings can be closely observed for the generation of signatures, the lack of blinding in 1.55, or earlier, may allow an attacker to gain information about the signature's k value and ultimately the private value as well.",
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.bouncycastle:bcprov-jdk14 and org.bouncycastle:bcprov-jdk15',
#        'publishedAt': '2018-10-17T16:24:00Z'},
#       'firstPatchedVersion': {'identifier': '1.56'},
#       'package': {'name': 'org.bouncycastle:bcprov-jdk15'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-17T16:23:55Z',
#       'vulnerableVersionRange': '< 1.56'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoyMzo1NSswODowMM0FIw=='},
#     {'node': {'advisory': {'identifiers': [{'type': 'GHSA',
#          'value': 'GHSA-qcj7-g2j5-g7r3'},
#         {'type': 'CVE', 'value': 'CVE-2016-1000342'}],
#        'description': "In the Bouncy Castle JCE Provider version 1.55 and earlier ECDSA does not fully validate ASN.1 encoding of signature on verification. It is possible to inject extra elements in the sequence making up the signature and still have it validate, which in some cases may allow the introduction of 'invisible' data into a signed structure.",
#        'severity': 'MODERATE',
#        'summary': 'Moderate severity vulnerability that affects org.bouncycastle:bcprov-jdk14 and org.bouncycastle:bcprov-jdk15',
#        'publishedAt': '2018-10-17T16:24:12Z'},
#       'firstPatchedVersion': {'identifier': '1.56'},
#       'package': {'name': 'org.bouncycastle:bcprov-jdk14'},
#       'severity': 'MODERATE',
#       'updatedAt': '2018-10-17T16:24:08Z',
#       'vulnerableVersionRange': '< 1.56'},
#      'cursor': 'Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoyNDowOCswODowMM0FJA=='}]}}}

# %%
last_cursor = result['data']['securityVulnerabilities']['edges'][-1]['cursor']
gen_query(last_cursor)
# Out:
# '\n    {\n      securityVulnerabilities(ecosystem: MAVEN, orderBy: {field: UPDATED_AT, direction: ASC}, first: 100\n    after:"Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoyNDowOCswODowMM0FJA=="\n      ) {\n        totalCount\n        edges {\n          node {\n            advisory {\n              identifiers {\n                type\n                value\n              }\n              description\n              severity\n              summary\n              publishedAt\n            }\n            firstPatchedVersion {\n              identifier\n            }\n            package {\n              name\n            }\n            severity\n            updatedAt\n            vulnerableVersionRange\n          }\n          cursor\n        }\n      }\n    }\n    '

# %%
res_all = []
query = gen_query()
while True:
    res_raw = run_query(query)
    res_curr = res_raw['data']['securityVulnerabilities']['edges']
    if len (res_curr) is 0:
        break
    res_all += res_curr
    last_cursor = res_curr[-1]['cursor']
    print(last_cursor)
    query = gen_query(last_cursor)
    time.sleep(5)
# Out:
# Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwMDoyNDowOCswODowMM0FJA==
# Y3Vyc29yOnYyOpK5MjAxOC0xMC0xOFQwNDoyOToyOCswODowMM0FiQ==
# Y3Vyc29yOnYyOpK5MjAxOC0xMC0yMFQwMDo0MjozNSswODowMM0F7g==
# Y3Vyc29yOnYyOpK5MjAxOC0xMi0yMlQwMTo0NzoxOSswODowMM0Gsg==
# Y3Vyc29yOnYyOpK5MjAxOS0wMy0xNFQyMzozNzo1NCswODowMM0IHA==
# Y3Vyc29yOnYyOpK5MjAxOS0wNS0zMFQxMTozMDowOCswODowMM0I8A==
# Y3Vyc29yOnYyOpK5MjAxOS0xMi0yN1QwMjoyMjowNCswODowMM0LZw==
# Y3Vyc29yOnYyOpK5MjAyMC0wNC0xNlQwNDo1NjoxOSswODowMM0Mxg==
# Y3Vyc29yOnYyOpK5MjAyMC0wNy0wOFQwMDo0NToxMCswODowMM0N4g==
# Y3Vyc29yOnYyOpK5MjAyMS0wMS0yMVQwNToxODoxNCswODowMM0WMg==

# %%
len(res_all)
# Out:
# 974

# %%
df = pd.DataFrame(columns=['CVE', 'package', 'severity', 'summary', 'description', 'publishedAt', 'vulnerableVersionRange', 'firstPatchedVersion'])

for index, vulnerability in enumerate(res_all):
    try:
        node = vulnerability['node']
        CVE = node['advisory']['identifiers'][-1]['value']
        package = node['package']['name']
        severity = node['severity']
        summary = node['advisory']['summary']
        description = node['advisory']['description']
#         publishedAt = parse(node['advisory']['publishedAt'])  # Oops, timezone not supported
        publishedAt = node['advisory']['publishedAt']
        vulnerableVersionRange = node['vulnerableVersionRange']
        firstPatchedVersion = node['firstPatchedVersion']['identifier'] if node['firstPatchedVersion'] else None
    except Exception as e:
        raise Exception(f"{e}:{node}")
    df.loc[index] = [CVE, package, severity, summary, description, publishedAt, vulnerableVersionRange, firstPatchedVersion]

# %%
df
# Out:
#                 CVE                                      package  severity  \
# 0     CVE-2016-9177                     com.sparkjava:spark-core  MODERATE
# 1     CVE-2016-9878              org.springframework:spring-core  MODERATE
# 2     CVE-2016-9878              org.springframework:spring-core  MODERATE
# 3     CVE-2016-9878              org.springframework:spring-core  MODERATE
# 4     CVE-2017-3159             org.apache.camel:camel-snakeyaml      HIGH
# ..              ...                                          ...       ...
# 969  CVE-2021-21234       eu.hinsch:spring-boot-actuator-logview      HIGH
# 970  CVE-2020-17519          org.apache.flink:flink-runtime_2.11  MODERATE
# 971  CVE-2020-17519          org.apache.flink:flink-runtime_2.12  MODERATE
# 972  CVE-2019-17359                org.bouncycastle:bcprov-jdk14  MODERATE
# 973  CVE-2021-20190  com.fasterxml.jackson.core:jackson-databind      HIGH
#
#                                                summary  \
# 0    Moderate severity vulnerability that affects c...
# 1    Moderate severity vulnerability that affects o...
# 2    Moderate severity vulnerability that affects o...
# 3    Moderate severity vulnerability that affects o...
# 4    High severity vulnerability that affects org.a...
# ..                                                 ...
# 969  Directory Traversal in spring-boot-actuator-lo...
# 970                     Path Traversal in Apache Flink
# 971                     Path Traversal in Apache Flink
# 972        Out-of-Memory Error in Bouncy Castle Crypto
# 973  Deserialization of untrusted data in jackson-d...
#
#                                            description           publishedAt  \
# 0    Directory traversal vulnerability in Spark 2.5...  2018-10-04T19:53:35Z
# 1    An issue was discovered in Pivotal Spring Fram...  2018-10-04T20:29:55Z
# 2    An issue was discovered in Pivotal Spring Fram...  2018-10-04T20:29:55Z
# 3    An issue was discovered in Pivotal Spring Fram...  2018-10-04T20:29:55Z
# 4    Apache Camel's camel-snakeyaml component is vu...  2018-10-16T17:21:42Z
# ..                                                 ...                   ...
# 969  ### Impact\nThe nature of this library is to e...  2021-01-05T17:29:40Z
# 970  A change introduced in Apache Flink 1.11.0 (an...  2021-01-06T20:01:34Z
# 971  A change introduced in Apache Flink 1.11.0 (an...  2021-01-06T20:01:34Z
# 972  The ASN.1 parser in Bouncy Castle Crypto (aka ...  2019-10-17T18:15:16Z
# 973  A flaw was found in jackson-databind before 2....  2021-01-20T21:20:15Z
#
#     vulnerableVersionRange firstPatchedVersion
# 0                  < 2.5.2               2.5.2
# 1                 < 3.2.18              3.2.18
# 2        >= 4.2.0, < 4.2.9               4.2.9
# 3        >= 4.3.0, < 4.3.5               4.3.5
# 4                 < 2.17.5              2.17.5
# ..                     ...                 ...
# 969               < 0.2.13              0.2.13
# 970               < 1.11.3              1.11.3
# 971               < 1.11.3              1.11.3
# 972                 = 1.63                1.64
# 973            <= 2.9.10.6            2.9.10.7
#
# [974 rows x 8 columns]

# %%
df.to_excel('data/vulnerabilities_github.xlsx')
